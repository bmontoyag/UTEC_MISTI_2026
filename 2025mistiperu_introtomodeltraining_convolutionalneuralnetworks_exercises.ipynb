# %% [markdown]
# <a href="https://colab.research.google.com/github/bmontoyag/UTEC_MISTI_2026/blob/main/2025mistiperu_introtomodeltraining_convolutionalneuralnetworks_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If you haven't already, please hit :**
#
# `File` -> `Save a Copy in Drive`
#
# **to copy this notebook to your Google drive, and work on a copy. If you don't do this, your changes won't be saved!**

# %% [markdown]
# # Model Training with Convolutional Neural Networks using MNIST

# %%
# @title
# ==============================================
# 0. Module imports
# ==============================================

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import datasets, transforms

# data manipulation
import pandas as pd
import numpy as np
import scipy.stats as st
import scipy

# plots
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pylab as pl

# classification algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler

# dimension reduction
from sklearn.decomposition import PCA

# cross-validation
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import model_selection

# parallel processing
from joblib import Parallel, delayed
import multiprocessing

# model evaluation
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings("ignore")

import seaborn as sns

device = "cpu"

# %% [markdown]
# Some visualization code. No need to understand this cell, but don't forget to run it!

# %%
# @title
from graphviz import Digraph

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#93D30C", "#8F00FF"]
def visualize(model):
    hidden_layers = []
    output_layer = 0
    layers = [layer for layer in model.modules() if type(layer) == torch.nn.Linear]

    # custom script to get all the shapes of a network's layers
    sizes = list()
    state_dict = net.state_dict()
    for idx, key in enumerate(state_dict.keys()):
      if key.endswith('weight'):
        output_size, input_size = state_dict[key].shape
        if idx == 0:
          sizes.append(input_size)
        sizes.append(output_size)

    input_layer = sizes[0]
    for layer in layers:
        if layer == layers[0]:
            hidden_layers.append(layer.out_features)

        else:
            if layer == layers[-1]:
                output_layer = layer.out_features
            else:
                hidden_layers.append(layer.out_features)

        last_layer_nodes = input_layer
        nodes_up = input_layer

    g = Digraph("g", filename='visualization_tmp')
    n = 0
    g.graph_attr.update(splines="false", nodesep="0.5", ranksep="0", rankdir='LR')
    # Input Layer
    with g.subgraph(name="cluster_input") as c:
          c.attr(color="white")
          for i in range(0, sizes[0]):
              n += 1
              c.node(str(n))
              c.attr(labeljust="1")
              c.attr(label="Input Layer", labelloc="bottom")
              c.attr(rank="same")
              c.node_attr.update(
                  width="0.65",
                  style="filled",
                  shape="circle",
                  color=HAPPY_COLORS_PALETTE[3],
                  fontcolor=HAPPY_COLORS_PALETTE[3],
              )
    for layer_idx in range(0, len(sizes) - 2):
        with g.subgraph(name="cluster_" + str(layer_idx + 1)) as c:
            c.attr(color="white")
            c.attr(rank="same")
            label = f'Hidden Layer {layer_idx + 1}'
            c.attr(labeljust="right", labelloc="b", label=label)
            for j in range(0, hidden_layers[layer_idx]):
                n += 1
                c.node(
                    str(n),
                    width="0.65",
                    shape="circle",
                    style="filled",
                    color=HAPPY_COLORS_PALETTE[0],
                    fontcolor=HAPPY_COLORS_PALETTE[0],
                )
                for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                    g.edge(str(h), str(n))
            last_layer_nodes = hidden_layers[layer_idx]
            nodes_up += hidden_layers[layer_idx]

    with g.subgraph(name="cluster_output") as c:
        c.attr(color="white")
        c.attr(rank="same")
        c.attr(labeljust="1")
        for i in range(1, output_layer + 1):
            n += 1
            c.node(
                str(n),
                width="0.65",
                shape="circle",
                style="filled",
                color=HAPPY_COLORS_PALETTE[4],
                fontcolor=HAPPY_COLORS_PALETTE[4],

            )
            for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                g.edge(str(h), str(n))
        c.attr(label="Output Layer", labelloc="bottom")
        c.node_attr.update(
            color="#2ecc71", style="filled", fontcolor="#2ecc71", shape="circle"
        )

    g.attr(arrowShape="none")
    g.edge_attr.update(arrowhead="none", color="#707070", penwidth="2")
    g.view()
    return g

# %% [markdown]
# ## Define DataLoaders
#
# This code creates **data loaders** for the **MNIST dataset** using PyTorch, which handles the loading and batching of training and testing data. The **batch sizes** are set to 64 for training and 1000 for testing to balance computation efficiency and memory usage. The `train_loader` shuffles the training data for better generalization, while the `test_loader` keeps the test data in a fixed order.
#
# Both data loaders apply a series of **transformations** to the images: converting them to tensors and normalizing pixel values to have a mean of 0.1307 and a standard deviation of 0.3081. These normalization values are calculated based on the MNIST dataset and help improve model convergence during training.

# %%
# Define the Batch Sizes
batch_size_train = 64
batch_size_test = 1000

# Training DataLoader
train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

# Testing DataLoader
test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 19.0MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 498kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.71MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.48MB/s]

# %% [markdown]
# ### ANALYZE: Explore Common Neural Network Layers
#
# In this exercise, we explore common PyTorch layers and use them to transform an example MNIST image.
#
# Tasks:
# 1. Explore `nn.Flatten()` - Converts a multi-dimensional tensor into a single-dimensional array.
# 2. Explore `nn.Linear()`– Applies a linear transformation to the input.
# 3. Explore `nn.ReLU()`– Introduces non-linearity to the network.
# 4. Explore `nn.Sequential()`– Combines layers into a sequence.
# 5. Explore `nn.Softmax()`Converts raw scores (logits) into probabilities.

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)
input_image = images[0]
print(input_image.size())
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# #### TASK 1: nn.Flatten
#
# The `nn.Flatten()` layer reshapes a 2D image into a 1D array of pixel values. This is often the first step when using fully connected layers, as they require a flat input.

# %%
flatten = nn.Flatten()
flat_image = flatten(input_image)
print(flat_image.size())

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original image
ax[0].imshow(input_image.squeeze(), cmap='gray')
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')
ax[0].axis('off')

# Plot the flattened Image
ax[1].imshow(flat_image.detach().numpy(), cmap='gray', aspect='auto')
ax[1].set_title('Flattened Image (784 pixels)')
ax[1].set_xlabel('Pixel Index')
ax[1].set_ylabel('Pixel Value')

sns.despine()

plt.tight_layout()
plt.show()
# Out:
# torch.Size([1, 784])

# %% [markdown]
# #### TASK 2: nn.Linear
#
# The `nn.Linear()` layer applies a linear transformation to the input data using its weights and biases. This helps the network create a feature space.

# %%
layer1 = nn.Linear(in_features=28*28, out_features=20)
hidden1 = layer1(flat_image)
print(hidden1.size())

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original image
ax[0].imshow(input_image.squeeze(), cmap='gray')
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')
ax[0].axis('off')

# Hidden layer output as a bar chart
ax[1].bar(range(hidden1.size(1)), hidden1.detach().numpy().squeeze())
ax[1].set_title('Hidden Layer Output (20 features)')
ax[1].set_xlabel('Feature Index')
ax[1].set_ylabel('Feature Value')

sns.despine()

plt.tight_layout()
plt.show()
# Out:
# torch.Size([1, 20])

# %% [markdown]
# #### TASK 3: nn.ReLU
#
# The `nn.ReLU()` activation function introduces non-linearity into the model. Without non-linear functions, the network would be limited to learning only linear relationships.

# %%
hidden1_ReLU = nn.ReLU()(hidden1)

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey = True)

# Original image
ax[0].bar(range(hidden1.size(1)), hidden1.detach().numpy().squeeze())
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')

# Hidden layer output as a bar chart after ReLU
ax[1].bar(range(hidden1_ReLU.size(1)), hidden1_ReLU.detach().numpy().squeeze())
ax[1].set_title('Hidden Layer Output (ReLU Applied, 20 Features)')
ax[1].set_xlabel('Feature Index')
ax[1].set_ylabel('Feature Value')

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### TASK 4: nn.Sequential
#
# The `nn.Sequential()` module allows us to define a complete network by chaining multiple layers together. This creates a straightforward, ordered flow of data through the network.

# %%
seq_modules = nn.Sequential(
    flatten,
    layer1,
    nn.ReLU(),
    nn.Linear(20, 10)
)
logits = seq_modules(input_image)

# Capture outputs at each step
flattened = flatten(input_image)
layer1_output = layer1(flattened)
relu_output = nn.ReLU()(layer1_output)
logits = seq_modules(input_image)

# Plot the outputs
fig, axes = plt.subplots(1, 4, figsize=(15, 4))

axes[0].imshow(input_image.squeeze().numpy(), cmap='gray')
axes[0].set_title("Original Image")

axes[1].imshow(flattened.detach().numpy(), cmap='gray', aspect='auto')
axes[1].set_title("Flattened")

axes[2].bar(range(20), layer1_output.detach().numpy().squeeze())
axes[2].set_title("Layer 1 Output")

axes[3].bar(range(10), logits.detach().numpy().squeeze())
axes[3].set_title("Logits (Output)")

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### TASK 5: nn.Softmax
#
# The `nn.Softmax()` layer converts raw logits into probabilities that sum to 1. It’s typically applied to the final layer of a classification network to produce class probabilities.

# %%
# Apply Softmax to convert logits to probabilities
softmax = nn.Softmax(dim=1)
pred_probab = softmax(logits)

# Plot the logits and the resulting probabilities
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Logits (Before Softmax)
axes[0].bar(range(10), logits.squeeze().detach().numpy())
axes[0].set_title("Logits (Before Softmax)")
axes[0].set_xlabel("Class Index")
axes[0].set_ylabel("Value")

# Predicted Probabilities (After Softmax)
axes[1].bar(range(10), pred_probab.squeeze().detach().numpy())
axes[1].set_title("Predicted Probabilities (After Softmax)")
axes[1].set_xlabel("Class Index")
axes[1].set_ylabel("Probability")

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training a Simple Convolutional Network
#
# The `train()` function is responsible for updating the network's parameters during the **training phase** using data from the training set. It sets the network to **training mode**, enabling layers like dropout that improve generalization. For **fully connected networks**, the input data is flattened into a 1D vector before being passed to the network, but this step is **skipped for convolutional neural networks (CNNs)**, which handle multi-dimensional inputs directly. During each batch, the function performs a **forward pass** to make predictions, calculates the **loss** using the Negative Log Likelihood function, and performs **backpropagation** to update the network’s weights. The function tracks and logs the **training progress** to monitor performance over time.

# %%
# Note: network.train() puts the network into "nondeterministic mode".
# This doesn't matter for the fully connected network, but it will matter for convolutional networks.
# CNNs rely on preserving spatial structure, so the nondeterministic mode can impact results.
def train(network, optimizer, epoch, trainloader, flatten_data=True):

    network.train()  # Set the network to training mode
    loss_logs = list()  # Track the loss over time

    for batch_idx, (data, target) in enumerate(trainloader):
        # For fully connected networks, we flatten the image data to feed it into the network.
        # CNNs, however, expect multi-dimensional image inputs, so we skip flattening.
        if flatten_data:
            data = flatten(data)  # Flatten the image (only for fully connected networks)

        # Move data to GPU if available
        data, target = data.to(device), target.to(device)

        # Zero the gradients from the previous batch
        optimizer.zero_grad()

        # Perform the forward pass through the network
        output = network(data)

        # Compute the loss using the Negative Log Likelihood loss function
        # This loss function is often used for classification tasks with multiple classes.
        loss = F.nll_loss(output, target)

        # Backpropagation: Calculate the gradients of the loss with respect to the network's parameters
        loss.backward()

        # Perform the optimization step: Update the network's parameters
        optimizer.step()

        # Print training progress at regular intervals
        if batch_idx % log_interval == 0:
            examples_shown = batch_idx * len(data)
            total_examples = len(trainloader.dataset)
            fraction_shown = round(examples_shown / total_examples * 100.0, 2)
            rounded_loss = round(loss.item(), 4)
            print(f'Train Epoch {epoch} Progress: {fraction_shown}%\tLoss: {rounded_loss}')

            examples_so_far = batch_idx * len(data) + epoch * len(trainloader.dataset)
            loss_logs.append((examples_so_far, loss.item()))

    return loss_logs

# %% [markdown]
# This `test()` function evaluates the performance of a trained neural network on unseen data from the test set. It puts the network into **evaluation mode** to ensure consistent behavior by disabling layers like dropout, which are only active during training. The function then loops through the test data, performs a **forward pass** to generate predictions, and calculates both the **average loss** and **accuracy**. For fully connected networks, the input data must be **flattened into a 1D vector** before being passed to the network, but this step is unnecessary for **convolutional neural networks (CNNs)**, which process multi-dimensional image data directly. The function finally prints the results, helping us assess how well the model generalizes to new data.

# %%
def test(network, flatten_data=True):
    # Set the network to evaluation mode.
    # This disables certain behaviors like dropout that are only used during training.
    network.eval()

    # Initialize test loss and correct predictions counters
    test_loss = 0
    correct = 0

    # Disable gradient calculation for efficiency since we are only testing the model.
    with torch.no_grad():
        for data, target in test_loader:
            # For fully connected networks, flatten the image data into a 1D vector.
            # CNNs expect multi-dimensional image inputs, so flattening is unnecessary for them.
            if flatten_data:
                data = flatten(data)

            # Move data and target to the GPU if available
            data, target = data.to(device), target.to(device)

            # Perform a forward pass through the network
            output = network(data)

            # Calculate the cumulative test loss using Negative Log Likelihood loss
            test_loss += F.nll_loss(output, target, size_average=False).item()

            # Get the predicted class for each input sample
            pred = output.data.max(1, keepdim=True)[1]

            # Count the number of correct predictions
            correct += pred.eq(target.data.view_as(pred)).sum()

    # Calculate the average test loss by dividing by the number of samples
    test_loss /= len(test_loader.dataset)

    # Calculate the test accuracy as a percentage
    accuracy = round(100. * correct.item() / len(test_loader.dataset), 2)

    # Print the test loss and accuracy
    print(f'\nTest set: Avg loss {round(test_loss, 4)}, Accuracy {accuracy}%\n')

    # Return the test loss and accuracy for logging purposes
    return test_loss, accuracy

# %% [markdown]
# ### EXERCISE: Define a Convolutional Neural Network
#
# Tasks:
# 1. Define a convolutional network with the following architecture.
#
#   - Define the CNN layers.
#
#     A. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second convolutional layer using `nn.Conv2d()`.
#       - Input channels = 1 (grayscale image)
#       - Output channels = 10
#       - Kernel size = 5
#
#     B. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second convolutional layer using `nn.Conv2d()`.
#       - Input channels = 10 (from the previous layer's output)
#       - Output channels = 20
#       - Kernel size = 5
#
#     C. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to add a dropout layer using `nn.Dropout2d()`.
#
#     D. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the first fully connected layer using `nn.Linear()`.
#       - Input features = 320 (flattened feature maps)
#       - Output features = 50
#
#     E. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second fully connected layer using `nn.Linear()`.
#       - Input features = 50 (from the previous fully connected layer)
#       - Output features = 10 (number of classes)
#
#   - Define the forward pass of the CNN.
#
#     F. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply the first convolutional layer followed by ReLU activation and 2x2 max pooling.
#
#     G. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply the second convolutional layer followed by a dropout layer.
#
#     H. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply 2x2 max pooling to the output of the second convolutional layer.
#
#     I. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a ReLU activation to introduce non-linearity
#
#     J. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a fully connected layer with a ReLU activation.
#
#     K. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a fully connected layer.

# %%
# TASK 1 EXERCISE

# Define the convolutional neural network (CNN) architecture
class ConvNet(nn.Module):

    def __init__(self):
        super(ConvNet, self).__init__()

        # First convolutional layer:
        # - 1 input channel (grayscale image)
        # - 10 output channels (feature maps)
        # - 5x5 kernel size (learns 5x5 filters to detect patterns)
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5) # QUESTION A

        # Second convolutional layer:
        # - Takes 10 input feature maps from conv1
        # - Produces 20 output feature maps
        # - 5x5 kernel size
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5) # QUESTION B

        # Dropout layer to reduce overfitting by randomly dropping units during training
        self.conv2_drop = nn.Dropout2d() # QUESTION C

        # First fully connected layer:
        # - 320 input features (flattened feature maps after convolutions)
        # - 50 output features (reduces dimensionality for classification)
        self.fc1 = nn.Linear(320, 50) # QUESTION D

        # Second fully connected layer:
        # - 50 input features from the previous layer
        # - 10 output features corresponding to the number of classes
        self.fc2 = nn.Linear(50, 10) # QUESTION E

    def forward(self, x):
        # First convolutional layer followed by:
        # - ReLU activation (introduces non-linearity)
        # - Max pooling (reduces dimensionality by taking the max value from 2x2 regions)
        x = F.relu(F.max_pool2d(self.conv1(x), 2)) # QUESTION F

        # Second convolutional layer followed by dropout:
        # - Helps reduce overfitting by randomly dropping out units
        x = self.conv2(self.conv2_drop(x)) # QUESTION G

        # Apply max pooling to reduce the feature map size
        # - Uses a 2x2 pooling region
        x = F.max_pool2d(x, 2) # QUESTION H

        # Apply ReLU activation to introduce non-linearity
        x = F.relu(x) # QUESTION I

        # Flatten the output to a 1D vector before passing it to fully connected layers
        # - The input size is reshaped to (-1, 320), where -1 infers the batch size
        x = x.view(-1, 320)

        # Apply the first fully connected layer followed by ReLU activation
        x = F.relu(self.fc1(x)) # QUESTION J

        # Apply dropout to the fully connected layer's output to reduce overfitting
        # - Dropout is only applied during training
        x = F.dropout(x, training=self.training)

        # Apply the second fully connected layer (output layer)
        # - Produces 10 output values corresponding to class scores
        x = self.fc2(x) # QUESTION K

        # Return the log of softmax probabilities for classification
        # - Converts the output scores into a categorical probability distribution
        return F.log_softmax(x)

# %% [markdown]
# ### EXERCISE: Train a Convolutional Neural Network with MNIST
#
# Tasks:
# 1. Set Up Your Environment and Define the Network
#   - Define key hyperparameters to control the training process.
#   - Create an instance of your CNN model using `ConvNet()`.
#   - Move the model to the appropriate device (CPU/GPU).
#   - Configure the optimizer using `optim.SGD()`.
# 2. Train Your CNN Model.
#   - Train your model for the specified number of epochs using the `train()` function.
# 3. Evaluate and Visualize the Model’s Performance.
#   - Use the `plot_results()` function to visualize:
#     - Training Loss and Test Loss Over Time
#     - Test Accuracy Over Epochs
#     - Analyze the plots to assess your model's performance.

# %% [markdown]
# #### TASK 1: Prepare your Environment to Train your CNN

# %%
# TASK 1 EXERCISE

# Define hyperparameters
# Hyperparameters control the behavior of the training process.

learning_rate = 0.01  # Controls how large the weight updates are during training.
# A smaller learning rate leads to slower but more stable convergence.
# A larger learning rate can speed up convergence but may cause instability.

momentum = 0.9
# Momentum helps accelerate convergence by adding a fraction of the previous update to the current update.
# This helps the model avoid getting stuck in local minima and smooths the optimization process.

n_epochs = 2
# Number of complete passes through the training dataset during training.
# Increasing the number of epochs can improve performance, but may lead to overfitting if too high.

log_interval = 10
# How often (in batches) we print the training progress.
# For example, a log_interval of 10 means the network will print updates every 10 batches.

# Initialize the convolutional network
conv_network = ConvNet()

# Move the network to the GPU if available
conv_network.to(device)

# Define the optimizer
# We're using SGD (Stochastic Gradient Descent) with the specified learning rate and momentum.
conv_optimizer = optim.SGD(conv_network.parameters(), lr=learning_rate, momentum=momentum)

# %% [markdown]
# #### TASK 2: Train your Model

# %%
# TASK 2 EXERCISE

# Initialize lists to track test accuracy, test losses, and training losses
test_accuracies, test_losses, train_losses = list(), list(), list()
total_examples_seen = 0  # Tracks the total number of examples processed during training

# Training loop over the specified number of epochs
for epoch in range(n_epochs):

    # Run the test phase before training each epoch to log initial performance
    test_loss, test_accuracy = test(conv_network, flatten_data=False)

    # Train the network on the training dataset for the current epoch
    train_loss_logs = train(conv_network, conv_optimizer, epoch, train_loader, flatten_data=False)

    # Log test performance
    test_accuracies.append((epoch, test_accuracy))  # Log accuracy for this epoch
    test_losses.append((total_examples_seen, test_loss))  # Log test loss

    # Log training losses
    train_losses.extend(train_loss_logs)

    # Update the total number of examples seen
    total_examples_seen = train_loss_logs[-1][0]

# Final test phase after completing all epochs
test_loss, test_accuracy = test(conv_network, flatten_data=False)
test_accuracies.append((n_epochs, test_accuracy))
test_losses.append((total_examples_seen, test_loss))

# At the end of the training process, we have:
# - test_accuracies: A list tracking the model's accuracy on the test set after each epoch.
# - test_losses: A list tracking the test loss after each epoch.
# - train_losses: A detailed log of the training loss over time.
# Out:
# Test set: Avg loss 2.3101, Accuracy 10.13%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3332
# Train Epoch 0 Progress: 1.07%	Loss: 2.2841
# Train Epoch 0 Progress: 2.13%	Loss: 2.2604
# Train Epoch 0 Progress: 3.2%	Loss: 2.0876
# Train Epoch 0 Progress: 4.27%	Loss: 1.6991
# Train Epoch 0 Progress: 5.33%	Loss: 1.3894
# Train Epoch 0 Progress: 6.4%	Loss: 1.2831
# Train Epoch 0 Progress: 7.47%	Loss: 0.9415
# Train Epoch 0 Progress: 8.53%	Loss: 1.0912
# Train Epoch 0 Progress: 9.6%	Loss: 0.9878
# Train Epoch 0 Progress: 10.67%	Loss: 0.8416
# Train Epoch 0 Progress: 11.73%	Loss: 1.3287
# Train Epoch 0 Progress: 12.8%	Loss: 0.8168
# Train Epoch 0 Progress: 13.87%	Loss: 0.7176
# Train Epoch 0 Progress: 14.93%	Loss: 0.6471
# Train Epoch 0 Progress: 16.0%	Loss: 0.5414
# Train Epoch 0 Progress: 17.07%	Loss: 0.8085
# Train Epoch 0 Progress: 18.13%	Loss: 0.7939
# Train Epoch 0 Progress: 19.2%	Loss: 0.5916
# Train Epoch 0 Progress: 20.27%	Loss: 0.6377
# Train Epoch 0 Progress: 21.33%	Loss: 0.791
# Train Epoch 0 Progress: 22.4%	Loss: 0.8857
# Train Epoch 0 Progress: 23.47%	Loss: 0.621
# Train Epoch 0 Progress: 24.53%	Loss: 0.5213
# Train Epoch 0 Progress: 25.6%	Loss: 0.4739
# Train Epoch 0 Progress: 26.67%	Loss: 0.4415
# Train Epoch 0 Progress: 27.73%	Loss: 0.6366
# Train Epoch 0 Progress: 28.8%	Loss: 0.5331
# Train Epoch 0 Progress: 29.87%	Loss: 0.3616
# Train Epoch 0 Progress: 30.93%	Loss: 0.4288
# Train Epoch 0 Progress: 32.0%	Loss: 0.5004
# Train Epoch 0 Progress: 33.07%	Loss: 0.67
# Train Epoch 0 Progress: 34.13%	Loss: 0.3215
# Train Epoch 0 Progress: 35.2%	Loss: 0.6045
# Train Epoch 0 Progress: 36.27%	Loss: 0.3331
# Train Epoch 0 Progress: 37.33%	Loss: 0.2433
# Train Epoch 0 Progress: 38.4%	Loss: 0.5574
# Train Epoch 0 Progress: 39.47%	Loss: 0.2402
# Train Epoch 0 Progress: 40.53%	Loss: 0.4381
# Train Epoch 0 Progress: 41.6%	Loss: 0.3959
# Train Epoch 0 Progress: 42.67%	Loss: 0.4954
# Train Epoch 0 Progress: 43.73%	Loss: 0.4311
# Train Epoch 0 Progress: 44.8%	Loss: 0.2994
# Train Epoch 0 Progress: 45.87%	Loss: 0.4652
# Train Epoch 0 Progress: 46.93%	Loss: 0.2425
# Train Epoch 0 Progress: 48.0%	Loss: 0.2456
# Train Epoch 0 Progress: 49.07%	Loss: 0.257
# Train Epoch 0 Progress: 50.13%	Loss: 0.3116
# Train Epoch 0 Progress: 51.2%	Loss: 0.3463
# Train Epoch 0 Progress: 52.27%	Loss: 0.318
# Train Epoch 0 Progress: 53.33%	Loss: 0.156
# Train Epoch 0 Progress: 54.4%	Loss: 0.5247
# Train Epoch 0 Progress: 55.47%	Loss: 0.2825
# Train Epoch 0 Progress: 56.53%	Loss: 0.3197
# Train Epoch 0 Progress: 57.6%	Loss: 0.2368
# Train Epoch 0 Progress: 58.67%	Loss: 0.2899
# Train Epoch 0 Progress: 59.73%	Loss: 0.6003
# Train Epoch 0 Progress: 60.8%	Loss: 0.3055
# Train Epoch 0 Progress: 61.87%	Loss: 0.311
# Train Epoch 0 Progress: 62.93%	Loss: 0.4724
# Train Epoch 0 Progress: 64.0%	Loss: 0.2905
# Train Epoch 0 Progress: 65.07%	Loss: 0.4353
# Train Epoch 0 Progress: 66.13%	Loss: 0.2771
# Train Epoch 0 Progress: 67.2%	Loss: 0.3597
# Train Epoch 0 Progress: 68.27%	Loss: 0.264
# Train Epoch 0 Progress: 69.33%	Loss: 0.2906
# Train Epoch 0 Progress: 70.4%	Loss: 0.198
# Train Epoch 0 Progress: 71.47%	Loss: 0.47
# Train Epoch 0 Progress: 72.53%	Loss: 0.1306
# Train Epoch 0 Progress: 73.6%	Loss: 0.2562
# Train Epoch 0 Progress: 74.67%	Loss: 0.1614
# Train Epoch 0 Progress: 75.73%	Loss: 0.3935
# Train Epoch 0 Progress: 76.8%	Loss: 0.4702
# Train Epoch 0 Progress: 77.87%	Loss: 0.295
# Train Epoch 0 Progress: 78.93%	Loss: 0.3349
# Train Epoch 0 Progress: 80.0%	Loss: 0.4981
# Train Epoch 0 Progress: 81.07%	Loss: 0.3301
# Train Epoch 0 Progress: 82.13%	Loss: 0.3514
# Train Epoch 0 Progress: 83.2%	Loss: 0.3355
# Train Epoch 0 Progress: 84.27%	Loss: 0.4013
# Train Epoch 0 Progress: 85.33%	Loss: 0.2866
# Train Epoch 0 Progress: 86.4%	Loss: 0.4529
# Train Epoch 0 Progress: 87.47%	Loss: 0.1638
# Train Epoch 0 Progress: 88.53%	Loss: 0.2301
# Train Epoch 0 Progress: 89.6%	Loss: 0.4096
# Train Epoch 0 Progress: 90.67%	Loss: 0.3575
# Train Epoch 0 Progress: 91.73%	Loss: 0.3992
# Train Epoch 0 Progress: 92.8%	Loss: 0.2703
# Train Epoch 0 Progress: 93.87%	Loss: 0.2749
# Train Epoch 0 Progress: 94.93%	Loss: 0.4735
# Train Epoch 0 Progress: 96.0%	Loss: 0.1507
# Train Epoch 0 Progress: 97.07%	Loss: 0.2288
# Train Epoch 0 Progress: 98.13%	Loss: 0.2012
# Train Epoch 0 Progress: 99.2%	Loss: 0.2812
#
# Test set: Avg loss 0.1006, Accuracy 97.11%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.3458
# Train Epoch 1 Progress: 1.07%	Loss: 0.3505
# Train Epoch 1 Progress: 2.13%	Loss: 0.2009
# Train Epoch 1 Progress: 3.2%	Loss: 0.4296
# Train Epoch 1 Progress: 4.27%	Loss: 0.2906
# Train Epoch 1 Progress: 5.33%	Loss: 0.1963
# Train Epoch 1 Progress: 6.4%	Loss: 0.2857
# Train Epoch 1 Progress: 7.47%	Loss: 0.4203
# Train Epoch 1 Progress: 8.53%	Loss: 0.2952
# Train Epoch 1 Progress: 9.6%	Loss: 0.1213
# Train Epoch 1 Progress: 10.67%	Loss: 0.1634
# Train Epoch 1 Progress: 11.73%	Loss: 0.2738
# Train Epoch 1 Progress: 12.8%	Loss: 0.5292
# Train Epoch 1 Progress: 13.87%	Loss: 0.206
# Train Epoch 1 Progress: 14.93%	Loss: 0.5455
# Train Epoch 1 Progress: 16.0%	Loss: 0.2105
# Train Epoch 1 Progress: 17.07%	Loss: 0.4914
# Train Epoch 1 Progress: 18.13%	Loss: 0.1456
# Train Epoch 1 Progress: 19.2%	Loss: 0.1979
# Train Epoch 1 Progress: 20.27%	Loss: 0.2887
# Train Epoch 1 Progress: 21.33%	Loss: 0.2084
# Train Epoch 1 Progress: 22.4%	Loss: 0.2934
# Train Epoch 1 Progress: 23.47%	Loss: 0.1184
# Train Epoch 1 Progress: 24.53%	Loss: 0.3326
# Train Epoch 1 Progress: 25.6%	Loss: 0.1382
# Train Epoch 1 Progress: 26.67%	Loss: 0.1352
# Train Epoch 1 Progress: 27.73%	Loss: 0.3263
# Train Epoch 1 Progress: 28.8%	Loss: 0.3412
# Train Epoch 1 Progress: 29.87%	Loss: 0.2931
# Train Epoch 1 Progress: 30.93%	Loss: 0.42
# Train Epoch 1 Progress: 32.0%	Loss: 0.1437
# Train Epoch 1 Progress: 33.07%	Loss: 0.3422
# Train Epoch 1 Progress: 34.13%	Loss: 0.2721
# Train Epoch 1 Progress: 35.2%	Loss: 0.1576
# Train Epoch 1 Progress: 36.27%	Loss: 0.2732
# Train Epoch 1 Progress: 37.33%	Loss: 0.3524
# Train Epoch 1 Progress: 38.4%	Loss: 0.1022
# Train Epoch 1 Progress: 39.47%	Loss: 0.3735
# Train Epoch 1 Progress: 40.53%	Loss: 0.2126
# Train Epoch 1 Progress: 41.6%	Loss: 0.1874
# Train Epoch 1 Progress: 42.67%	Loss: 0.2784
# Train Epoch 1 Progress: 43.73%	Loss: 0.177
# Train Epoch 1 Progress: 44.8%	Loss: 0.1771
# Train Epoch 1 Progress: 45.87%	Loss: 0.3014
# Train Epoch 1 Progress: 46.93%	Loss: 0.094
# Train Epoch 1 Progress: 48.0%	Loss: 0.0697
# Train Epoch 1 Progress: 49.07%	Loss: 0.2076
# Train Epoch 1 Progress: 50.13%	Loss: 0.2008
# Train Epoch 1 Progress: 51.2%	Loss: 0.2338
# Train Epoch 1 Progress: 52.27%	Loss: 0.1356
# Train Epoch 1 Progress: 53.33%	Loss: 0.1642
# Train Epoch 1 Progress: 54.4%	Loss: 0.0918
# Train Epoch 1 Progress: 55.47%	Loss: 0.242
# Train Epoch 1 Progress: 56.53%	Loss: 0.0828
# Train Epoch 1 Progress: 57.6%	Loss: 0.0634
# Train Epoch 1 Progress: 58.67%	Loss: 0.2056
# Train Epoch 1 Progress: 59.73%	Loss: 0.2781
# Train Epoch 1 Progress: 60.8%	Loss: 0.3079
# Train Epoch 1 Progress: 61.87%	Loss: 0.1356
# Train Epoch 1 Progress: 62.93%	Loss: 0.4437
# Train Epoch 1 Progress: 64.0%	Loss: 0.1466
# Train Epoch 1 Progress: 65.07%	Loss: 0.2162
# Train Epoch 1 Progress: 66.13%	Loss: 0.1322
# Train Epoch 1 Progress: 67.2%	Loss: 0.1309
# Train Epoch 1 Progress: 68.27%	Loss: 0.2521
# Train Epoch 1 Progress: 69.33%	Loss: 0.2727
# Train Epoch 1 Progress: 70.4%	Loss: 0.2205
# Train Epoch 1 Progress: 71.47%	Loss: 0.2851
# Train Epoch 1 Progress: 72.53%	Loss: 0.1464
# Train Epoch 1 Progress: 73.6%	Loss: 0.3361
# Train Epoch 1 Progress: 74.67%	Loss: 0.2154
# Train Epoch 1 Progress: 75.73%	Loss: 0.181
# Train Epoch 1 Progress: 76.8%	Loss: 0.1233
# Train Epoch 1 Progress: 77.87%	Loss: 0.1396
# Train Epoch 1 Progress: 78.93%	Loss: 0.2966
# Train Epoch 1 Progress: 80.0%	Loss: 0.1036
# Train Epoch 1 Progress: 81.07%	Loss: 0.1425
# Train Epoch 1 Progress: 82.13%	Loss: 0.278
# Train Epoch 1 Progress: 83.2%	Loss: 0.1898
# Train Epoch 1 Progress: 84.27%	Loss: 0.2516
# Train Epoch 1 Progress: 85.33%	Loss: 0.4317
# Train Epoch 1 Progress: 86.4%	Loss: 0.1486
# Train Epoch 1 Progress: 87.47%	Loss: 0.0869
# Train Epoch 1 Progress: 88.53%	Loss: 0.288
# Train Epoch 1 Progress: 89.6%	Loss: 0.2761
# Train Epoch 1 Progress: 90.67%	Loss: 0.2546
# Train Epoch 1 Progress: 91.73%	Loss: 0.142
# Train Epoch 1 Progress: 92.8%	Loss: 0.4136
# Train Epoch 1 Progress: 93.87%	Loss: 0.0934
# Train Epoch 1 Progress: 94.93%	Loss: 0.1929
# Train Epoch 1 Progress: 96.0%	Loss: 0.187
# Train Epoch 1 Progress: 97.07%	Loss: 0.1129
# Train Epoch 1 Progress: 98.13%	Loss: 0.1656
# Train Epoch 1 Progress: 99.2%	Loss: 0.1554
#
# Test set: Avg loss 0.0679, Accuracy 97.99%

# %% [markdown]
# #### TASK 3: Assess the Performance of your Model

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_results(test_accuracies, test_losses, train_losses):
    """
    Plot training losses, test losses, and test accuracy over time.

    Parameters:
    - test_accuracies: List of tuples [(epoch, accuracy)], representing test accuracy over epochs.
    - test_losses: List of tuples [(epoch, loss)], representing test loss over examples seen.
    - train_losses: List of tuples [(example, loss)], representing training loss over examples seen.
    """
    # --- Plot Training and Test Losses ---
    plt.figure(figsize=(12, 6))

    # Extract values for training losses
    train_x, train_y = zip(*train_losses)

    # Extract values for test losses
    test_x, test_y = zip(*test_losses)

    # Plot training losses
    plt.plot(train_x, train_y, label='Training Loss', color='b', linestyle='-', marker='.')

    # Plot test losses
    plt.plot(test_x, test_y, label='Test Loss', color='r', linestyle='--', marker='o')

    # Formatting
    plt.xlabel('Examples Seen')
    plt.ylabel('Log Loss')
    plt.title('Training and Test Losses Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

    # --- Plot Test Accuracy ---
    plt.figure(figsize=(12, 6))

    # Extract values for test accuracy
    acc_x, acc_y = zip(*test_accuracies)

    # Plot test accuracy
    plt.plot(acc_x, acc_y, label='Test Accuracy', color='g', marker='o')

    # Formatting
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy Over Epochs')
    plt.legend()
    plt.grid(True)
    sns.despine()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_results(test_accuracies, test_losses, train_losses):
    """
    Plot training losses, test losses, and test accuracy over time.

    Parameters:
    - test_accuracies: List of tuples [(epoch, accuracy)], representing test accuracy over epochs.
    - test_losses: List of tuples [(epoch, loss)], representing test loss over examples seen.
    - train_losses: List of tuples [(example, loss)], representing training loss over examples seen.
    """
    # --- Plot Training and Test Losses ---
    plt.figure(figsize=(12, 6))

    # Extract values for training losses
    train_x, train_y = zip(*train_losses)

    # Extract values for test losses
    test_x, test_y = zip(*test_losses)

    # Plot training losses
    plt.plot(train_x, train_y, label='Training Loss', color='b', linestyle='-', marker='.')

    # Plot test losses
    plt.plot(test_x, test_y, label='Test Loss', color='r', linestyle='--', marker='o')

    # Formatting
    plt.xlabel('Examples Seen')
    plt.ylabel('Log Loss')
    plt.title('Training and Test Losses Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

    # --- Plot Test Accuracy ---
    plt.figure(figsize=(12, 6))

    # Extract values for test accuracy
    acc_x, acc_y = zip(*test_accuracies)

    # Plot test accuracy
    plt.plot(acc_x, acc_y, label='Test Accuracy', color='g', marker='o')

    # Formatting
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy Over Epochs')
    plt.legend()
    plt.grid(True)
    sns.despine()
    plt.show()

# TASK 3 EXERCISE

# Plot your Results using the function `plot_resolts
plot_results(test_accuracies, test_losses, train_losses)

# %% [markdown]
# # Appendices

# %% [markdown]
# ## Hyperparameter Tuning with CNNs

# %% [markdown]
# ### EXERCISE: Perform Hyperparameter Tuning to Improve Performance of your Convolutional Neural Network

# %%
from itertools import product

# Define ranges for hyperparameters
learning_rates = [0.001, 0.01, 0.1]
momentums = [0.5, 0.9]
batch_sizes = [32, 64, 128]

# Store results
results = []

# Hyperparameter tuning loop
for lr, momentum, batch_size in product(learning_rates, momentums, batch_sizes):
    print(f"Training with lr={lr}, momentum={momentum}, batch_size={batch_size}")

    # Update train loader with the current batch size
    train_loader = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('sample_data/', train=True, download=True,
                                   transform=torchvision.transforms.Compose([
                                       torchvision.transforms.ToTensor(),
                                       torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                   ])),
        batch_size=batch_size, shuffle=True)

    # Initialize network
    conv_network = ConvNet()
    conv_network.to(device)

    # Define optimizer
    conv_optimizer = optim.SGD(conv_network.parameters(), lr=lr, momentum=momentum)

    # Train and test
    test_accuracies, test_losses, train_losses = list(), list(), list()
    total_examples_seen = 0
    for epoch in range(n_epochs):
        test_loss, test_accuracy = test(conv_network, flatten_data=False)
        train_loss_logs = train(conv_network, conv_optimizer, epoch, train_loader, flatten_data=False)
        test_accuracies.append((epoch, test_accuracy))
        test_losses.append((total_examples_seen, test_loss))
        train_losses.extend(train_loss_logs)
        total_examples_seen = train_loss_logs[-1][0]
    test_loss, test_accuracy = test(conv_network, flatten_data=False)

    # Log the performance
    results.append({
        "lr": lr,
        "momentum": momentum,
        "batch_size": batch_size,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy
    })
# Out:
# Training with lr=0.001, momentum=0.5, batch_size=32
#
# Test set: Avg loss 2.3042, Accuracy 10.55%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3511
# Train Epoch 0 Progress: 0.53%	Loss: 2.4106
# Train Epoch 0 Progress: 1.07%	Loss: 2.3475
# Train Epoch 0 Progress: 1.6%	Loss: 2.304
# Train Epoch 0 Progress: 2.13%	Loss: 2.3604
# Train Epoch 0 Progress: 2.67%	Loss: 2.3404
# Train Epoch 0 Progress: 3.2%	Loss: 2.2902
# Train Epoch 0 Progress: 3.73%	Loss: 2.303
# Train Epoch 0 Progress: 4.27%	Loss: 2.3031
# Train Epoch 0 Progress: 4.8%	Loss: 2.3034
# Train Epoch 0 Progress: 5.33%	Loss: 2.2988
# Train Epoch 0 Progress: 5.87%	Loss: 2.2643
# Train Epoch 0 Progress: 6.4%	Loss: 2.2897
# Train Epoch 0 Progress: 6.93%	Loss: 2.2701
# Train Epoch 0 Progress: 7.47%	Loss: 2.2576
# Train Epoch 0 Progress: 8.0%	Loss: 2.3272
# Train Epoch 0 Progress: 8.53%	Loss: 2.3168
# Train Epoch 0 Progress: 9.07%	Loss: 2.2829
# Train Epoch 0 Progress: 9.6%	Loss: 2.3056
# Train Epoch 0 Progress: 10.13%	Loss: 2.2585
# Train Epoch 0 Progress: 10.67%	Loss: 2.2833
# Train Epoch 0 Progress: 11.2%	Loss: 2.2272
# Train Epoch 0 Progress: 11.73%	Loss: 2.3034
# Train Epoch 0 Progress: 12.27%	Loss: 2.259
# Train Epoch 0 Progress: 12.8%	Loss: 2.2521
# Train Epoch 0 Progress: 13.33%	Loss: 2.2608
# Train Epoch 0 Progress: 13.87%	Loss: 2.3123
# Train Epoch 0 Progress: 14.4%	Loss: 2.3014
# Train Epoch 0 Progress: 14.93%	Loss: 2.3074
# Train Epoch 0 Progress: 15.47%	Loss: 2.2402
# Train Epoch 0 Progress: 16.0%	Loss: 2.234
# Train Epoch 0 Progress: 16.53%	Loss: 2.2779
# Train Epoch 0 Progress: 17.07%	Loss: 2.2271
# Train Epoch 0 Progress: 17.6%	Loss: 2.2551
# Train Epoch 0 Progress: 18.13%	Loss: 2.2939
# Train Epoch 0 Progress: 18.67%	Loss: 2.2806
# Train Epoch 0 Progress: 19.2%	Loss: 2.2509
# Train Epoch 0 Progress: 19.73%	Loss: 2.226
# Train Epoch 0 Progress: 20.27%	Loss: 2.2635
# Train Epoch 0 Progress: 20.8%	Loss: 2.2316
# Train Epoch 0 Progress: 21.33%	Loss: 2.2515
# Train Epoch 0 Progress: 21.87%	Loss: 2.3167
# Train Epoch 0 Progress: 22.4%	Loss: 2.2557
# Train Epoch 0 Progress: 22.93%	Loss: 2.2172
# Train Epoch 0 Progress: 23.47%	Loss: 2.2497
# Train Epoch 0 Progress: 24.0%	Loss: 2.2189
# Train Epoch 0 Progress: 24.53%	Loss: 2.2495
# Train Epoch 0 Progress: 25.07%	Loss: 2.2321
# Train Epoch 0 Progress: 25.6%	Loss: 2.1954
# Train Epoch 0 Progress: 26.13%	Loss: 2.216
# Train Epoch 0 Progress: 26.67%	Loss: 2.251
# Train Epoch 0 Progress: 27.2%	Loss: 2.2368
# Train Epoch 0 Progress: 27.73%	Loss: 2.1249
# Train Epoch 0 Progress: 28.27%	Loss: 2.2431
# Train Epoch 0 Progress: 28.8%	Loss: 2.2435
# Train Epoch 0 Progress: 29.33%	Loss: 2.2156
# Train Epoch 0 Progress: 29.87%	Loss: 2.1174
# Train Epoch 0 Progress: 30.4%	Loss: 2.1891
# Train Epoch 0 Progress: 30.93%	Loss: 2.1941
# Train Epoch 0 Progress: 31.47%	Loss: 2.2115
# Train Epoch 0 Progress: 32.0%	Loss: 2.206
# Train Epoch 0 Progress: 32.53%	Loss: 2.1411
# Train Epoch 0 Progress: 33.07%	Loss: 2.1345
# Train Epoch 0 Progress: 33.6%	Loss: 2.1003
# Train Epoch 0 Progress: 34.13%	Loss: 2.1736
# Train Epoch 0 Progress: 34.67%	Loss: 2.1874
# Train Epoch 0 Progress: 35.2%	Loss: 2.1076
# Train Epoch 0 Progress: 35.73%	Loss: 2.1268
# Train Epoch 0 Progress: 36.27%	Loss: 2.1985
# Train Epoch 0 Progress: 36.8%	Loss: 2.1188
# Train Epoch 0 Progress: 37.33%	Loss: 2.0581
# Train Epoch 0 Progress: 37.87%	Loss: 2.0309
# Train Epoch 0 Progress: 38.4%	Loss: 2.1754
# Train Epoch 0 Progress: 38.93%	Loss: 2.0882
# Train Epoch 0 Progress: 39.47%	Loss: 2.0403
# Train Epoch 0 Progress: 40.0%	Loss: 2.1506
# Train Epoch 0 Progress: 40.53%	Loss: 2.0386
# Train Epoch 0 Progress: 41.07%	Loss: 2.0217
# Train Epoch 0 Progress: 41.6%	Loss: 2.1134
# Train Epoch 0 Progress: 42.13%	Loss: 1.9566
# Train Epoch 0 Progress: 42.67%	Loss: 2.0208
# Train Epoch 0 Progress: 43.2%	Loss: 1.9533
# Train Epoch 0 Progress: 43.73%	Loss: 2.047
# Train Epoch 0 Progress: 44.27%	Loss: 1.9066
# Train Epoch 0 Progress: 44.8%	Loss: 1.9042
# Train Epoch 0 Progress: 45.33%	Loss: 1.9948
# Train Epoch 0 Progress: 45.87%	Loss: 2.113
# Train Epoch 0 Progress: 46.4%	Loss: 1.9347
# Train Epoch 0 Progress: 46.93%	Loss: 1.9659
# Train Epoch 0 Progress: 47.47%	Loss: 1.8991
# Train Epoch 0 Progress: 48.0%	Loss: 1.954
# Train Epoch 0 Progress: 48.53%	Loss: 1.9115
# Train Epoch 0 Progress: 49.07%	Loss: 1.9948
# Train Epoch 0 Progress: 49.6%	Loss: 1.9233
# Train Epoch 0 Progress: 50.13%	Loss: 1.9685
# Train Epoch 0 Progress: 50.67%	Loss: 1.7472
# Train Epoch 0 Progress: 51.2%	Loss: 1.8416
# Train Epoch 0 Progress: 51.73%	Loss: 1.9178
# Train Epoch 0 Progress: 52.27%	Loss: 1.7289
# Train Epoch 0 Progress: 52.8%	Loss: 1.8086
# Train Epoch 0 Progress: 53.33%	Loss: 1.6843
# Train Epoch 0 Progress: 53.87%	Loss: 1.76
# Train Epoch 0 Progress: 54.4%	Loss: 1.6055
# Train Epoch 0 Progress: 54.93%	Loss: 1.6241
# Train Epoch 0 Progress: 55.47%	Loss: 1.8434
# Train Epoch 0 Progress: 56.0%	Loss: 1.7402
# Train Epoch 0 Progress: 56.53%	Loss: 1.7919
# Train Epoch 0 Progress: 57.07%	Loss: 1.642
# Train Epoch 0 Progress: 57.6%	Loss: 1.5468
# Train Epoch 0 Progress: 58.13%	Loss: 1.7206
# Train Epoch 0 Progress: 58.67%	Loss: 1.6669
# Train Epoch 0 Progress: 59.2%	Loss: 1.7013
# Train Epoch 0 Progress: 59.73%	Loss: 1.5953
# Train Epoch 0 Progress: 60.27%	Loss: 1.7146
# Train Epoch 0 Progress: 60.8%	Loss: 1.6787
# Train Epoch 0 Progress: 61.33%	Loss: 1.4357
# Train Epoch 0 Progress: 61.87%	Loss: 1.3192
# Train Epoch 0 Progress: 62.4%	Loss: 1.5513
# Train Epoch 0 Progress: 62.93%	Loss: 1.4425
# Train Epoch 0 Progress: 63.47%	Loss: 1.6099
# Train Epoch 0 Progress: 64.0%	Loss: 1.4294
# Train Epoch 0 Progress: 64.53%	Loss: 1.5234
# Train Epoch 0 Progress: 65.07%	Loss: 1.4807
# Train Epoch 0 Progress: 65.6%	Loss: 1.2411
# Train Epoch 0 Progress: 66.13%	Loss: 1.3002
# Train Epoch 0 Progress: 66.67%	Loss: 1.503
# Train Epoch 0 Progress: 67.2%	Loss: 1.4086
# Train Epoch 0 Progress: 67.73%	Loss: 1.5077
# Train Epoch 0 Progress: 68.27%	Loss: 1.3072
# Train Epoch 0 Progress: 68.8%	Loss: 1.2584
# Train Epoch 0 Progress: 69.33%	Loss: 1.6568
# Train Epoch 0 Progress: 69.87%	Loss: 1.3046
# Train Epoch 0 Progress: 70.4%	Loss: 1.3693
# Train Epoch 0 Progress: 70.93%	Loss: 1.4238
# Train Epoch 0 Progress: 71.47%	Loss: 1.2456
# Train Epoch 0 Progress: 72.0%	Loss: 1.4176
# Train Epoch 0 Progress: 72.53%	Loss: 1.246
# Train Epoch 0 Progress: 73.07%	Loss: 1.5077
# Train Epoch 0 Progress: 73.6%	Loss: 1.3517
# Train Epoch 0 Progress: 74.13%	Loss: 1.3771
# Train Epoch 0 Progress: 74.67%	Loss: 1.0759
# Train Epoch 0 Progress: 75.2%	Loss: 1.4115
# Train Epoch 0 Progress: 75.73%	Loss: 1.2475
# Train Epoch 0 Progress: 76.27%	Loss: 1.0133
# Train Epoch 0 Progress: 76.8%	Loss: 1.1144
# Train Epoch 0 Progress: 77.33%	Loss: 1.3122
# Train Epoch 0 Progress: 77.87%	Loss: 1.2356
# Train Epoch 0 Progress: 78.4%	Loss: 1.324
# Train Epoch 0 Progress: 78.93%	Loss: 1.1943
# Train Epoch 0 Progress: 79.47%	Loss: 1.1479
# Train Epoch 0 Progress: 80.0%	Loss: 1.1415
# Train Epoch 0 Progress: 80.53%	Loss: 0.9395
# Train Epoch 0 Progress: 81.07%	Loss: 0.9394
# Train Epoch 0 Progress: 81.6%	Loss: 1.1754
# Train Epoch 0 Progress: 82.13%	Loss: 1.5016
# Train Epoch 0 Progress: 82.67%	Loss: 1.2474
# Train Epoch 0 Progress: 83.2%	Loss: 1.0676
# Train Epoch 0 Progress: 83.73%	Loss: 1.0451
# Train Epoch 0 Progress: 84.27%	Loss: 0.9305
# Train Epoch 0 Progress: 84.8%	Loss: 1.0158
# Train Epoch 0 Progress: 85.33%	Loss: 1.2377
# Train Epoch 0 Progress: 85.87%	Loss: 1.0462
# Train Epoch 0 Progress: 86.4%	Loss: 1.0998
# Train Epoch 0 Progress: 86.93%	Loss: 0.8536
# Train Epoch 0 Progress: 87.47%	Loss: 0.9852
# Train Epoch 0 Progress: 88.0%	Loss: 1.0983
# Train Epoch 0 Progress: 88.53%	Loss: 0.9058
# Train Epoch 0 Progress: 89.07%	Loss: 1.0838
# Train Epoch 0 Progress: 89.6%	Loss: 0.8616
# Train Epoch 0 Progress: 90.13%	Loss: 1.1925
# Train Epoch 0 Progress: 90.67%	Loss: 1.1617
# Train Epoch 0 Progress: 91.2%	Loss: 1.0122
# Train Epoch 0 Progress: 91.73%	Loss: 1.1075
# Train Epoch 0 Progress: 92.27%	Loss: 0.9491
# Train Epoch 0 Progress: 92.8%	Loss: 1.0085
# Train Epoch 0 Progress: 93.33%	Loss: 1.2375
# Train Epoch 0 Progress: 93.87%	Loss: 0.9846
# Train Epoch 0 Progress: 94.4%	Loss: 1.1334
# Train Epoch 0 Progress: 94.93%	Loss: 0.9812
# Train Epoch 0 Progress: 95.47%	Loss: 1.0188
# Train Epoch 0 Progress: 96.0%	Loss: 1.2912
# Train Epoch 0 Progress: 96.53%	Loss: 1.1729
# Train Epoch 0 Progress: 97.07%	Loss: 1.2257
# Train Epoch 0 Progress: 97.6%	Loss: 0.7791
# Train Epoch 0 Progress: 98.13%	Loss: 1.1313
# Train Epoch 0 Progress: 98.67%	Loss: 1.049
# Train Epoch 0 Progress: 99.2%	Loss: 1.2476
# Train Epoch 0 Progress: 99.73%	Loss: 1.1403
#
# Test set: Avg loss 0.5603, Accuracy 87.1%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.9079
# Train Epoch 1 Progress: 0.53%	Loss: 1.1411
# Train Epoch 1 Progress: 1.07%	Loss: 1.1122
# Train Epoch 1 Progress: 1.6%	Loss: 1.0676
# Train Epoch 1 Progress: 2.13%	Loss: 0.9758
# Train Epoch 1 Progress: 2.67%	Loss: 1.1829
# Train Epoch 1 Progress: 3.2%	Loss: 1.1341
# Train Epoch 1 Progress: 3.73%	Loss: 1.1371
# Train Epoch 1 Progress: 4.27%	Loss: 1.3771
# Train Epoch 1 Progress: 4.8%	Loss: 1.1177
# Train Epoch 1 Progress: 5.33%	Loss: 0.7332
# Train Epoch 1 Progress: 5.87%	Loss: 0.8163
# Train Epoch 1 Progress: 6.4%	Loss: 0.7843
# Train Epoch 1 Progress: 6.93%	Loss: 0.5848
# Train Epoch 1 Progress: 7.47%	Loss: 0.7363
# Train Epoch 1 Progress: 8.0%	Loss: 0.768
# Train Epoch 1 Progress: 8.53%	Loss: 0.8576
# Train Epoch 1 Progress: 9.07%	Loss: 0.8518
# Train Epoch 1 Progress: 9.6%	Loss: 0.9583
# Train Epoch 1 Progress: 10.13%	Loss: 1.1643
# Train Epoch 1 Progress: 10.67%	Loss: 1.1804
# Train Epoch 1 Progress: 11.2%	Loss: 0.8132
# Train Epoch 1 Progress: 11.73%	Loss: 0.7793
# Train Epoch 1 Progress: 12.27%	Loss: 0.9245
# Train Epoch 1 Progress: 12.8%	Loss: 0.6964
# Train Epoch 1 Progress: 13.33%	Loss: 1.0956
# Train Epoch 1 Progress: 13.87%	Loss: 1.1124
# Train Epoch 1 Progress: 14.4%	Loss: 0.6028
# Train Epoch 1 Progress: 14.93%	Loss: 1.073
# Train Epoch 1 Progress: 15.47%	Loss: 0.8701
# Train Epoch 1 Progress: 16.0%	Loss: 0.9377
# Train Epoch 1 Progress: 16.53%	Loss: 0.8287
# Train Epoch 1 Progress: 17.07%	Loss: 0.7696
# Train Epoch 1 Progress: 17.6%	Loss: 0.7637
# Train Epoch 1 Progress: 18.13%	Loss: 0.858
# Train Epoch 1 Progress: 18.67%	Loss: 0.7254
# Train Epoch 1 Progress: 19.2%	Loss: 0.8316
# Train Epoch 1 Progress: 19.73%	Loss: 1.0833
# Train Epoch 1 Progress: 20.27%	Loss: 0.9185
# Train Epoch 1 Progress: 20.8%	Loss: 0.814
# Train Epoch 1 Progress: 21.33%	Loss: 0.6993
# Train Epoch 1 Progress: 21.87%	Loss: 0.6648
# Train Epoch 1 Progress: 22.4%	Loss: 0.9258
# Train Epoch 1 Progress: 22.93%	Loss: 1.3622
# Train Epoch 1 Progress: 23.47%	Loss: 0.7405
# Train Epoch 1 Progress: 24.0%	Loss: 0.8538
# Train Epoch 1 Progress: 24.53%	Loss: 0.9862
# Train Epoch 1 Progress: 25.07%	Loss: 0.9028
# Train Epoch 1 Progress: 25.6%	Loss: 0.9048
# Train Epoch 1 Progress: 26.13%	Loss: 0.7003
# Train Epoch 1 Progress: 26.67%	Loss: 0.7483
# Train Epoch 1 Progress: 27.2%	Loss: 0.5928
# Train Epoch 1 Progress: 27.73%	Loss: 0.5902
# Train Epoch 1 Progress: 28.27%	Loss: 0.8659
# Train Epoch 1 Progress: 28.8%	Loss: 0.8158
# Train Epoch 1 Progress: 29.33%	Loss: 0.7019
# Train Epoch 1 Progress: 29.87%	Loss: 0.7275
# Train Epoch 1 Progress: 30.4%	Loss: 0.8369
# Train Epoch 1 Progress: 30.93%	Loss: 1.3859
# Train Epoch 1 Progress: 31.47%	Loss: 0.6294
# Train Epoch 1 Progress: 32.0%	Loss: 0.6972
# Train Epoch 1 Progress: 32.53%	Loss: 0.6008
# Train Epoch 1 Progress: 33.07%	Loss: 0.8887
# Train Epoch 1 Progress: 33.6%	Loss: 0.7587
# Train Epoch 1 Progress: 34.13%	Loss: 0.4777
# Train Epoch 1 Progress: 34.67%	Loss: 0.9676
# Train Epoch 1 Progress: 35.2%	Loss: 0.6544
# Train Epoch 1 Progress: 35.73%	Loss: 0.9546
# Train Epoch 1 Progress: 36.27%	Loss: 1.1699
# Train Epoch 1 Progress: 36.8%	Loss: 0.8959
# Train Epoch 1 Progress: 37.33%	Loss: 0.7896
# Train Epoch 1 Progress: 37.87%	Loss: 0.7442
# Train Epoch 1 Progress: 38.4%	Loss: 0.625
# Train Epoch 1 Progress: 38.93%	Loss: 0.8337
# Train Epoch 1 Progress: 39.47%	Loss: 0.632
# Train Epoch 1 Progress: 40.0%	Loss: 0.8605
# Train Epoch 1 Progress: 40.53%	Loss: 0.4707
# Train Epoch 1 Progress: 41.07%	Loss: 0.6171
# Train Epoch 1 Progress: 41.6%	Loss: 0.6207
# Train Epoch 1 Progress: 42.13%	Loss: 0.7129
# Train Epoch 1 Progress: 42.67%	Loss: 1.0286
# Train Epoch 1 Progress: 43.2%	Loss: 0.8079
# Train Epoch 1 Progress: 43.73%	Loss: 0.8222
# Train Epoch 1 Progress: 44.27%	Loss: 0.5917
# Train Epoch 1 Progress: 44.8%	Loss: 0.4986
# Train Epoch 1 Progress: 45.33%	Loss: 0.6694
# Train Epoch 1 Progress: 45.87%	Loss: 0.6663
# Train Epoch 1 Progress: 46.4%	Loss: 0.8347
# Train Epoch 1 Progress: 46.93%	Loss: 0.8487
# Train Epoch 1 Progress: 47.47%	Loss: 0.9291
# Train Epoch 1 Progress: 48.0%	Loss: 0.5883
# Train Epoch 1 Progress: 48.53%	Loss: 0.374
# Train Epoch 1 Progress: 49.07%	Loss: 0.9404
# Train Epoch 1 Progress: 49.6%	Loss: 1.1175
# Train Epoch 1 Progress: 50.13%	Loss: 0.6791
# Train Epoch 1 Progress: 50.67%	Loss: 0.9597
# Train Epoch 1 Progress: 51.2%	Loss: 0.8768
# Train Epoch 1 Progress: 51.73%	Loss: 1.0037
# Train Epoch 1 Progress: 52.27%	Loss: 0.6128
# Train Epoch 1 Progress: 52.8%	Loss: 0.7397
# Train Epoch 1 Progress: 53.33%	Loss: 0.8055
# Train Epoch 1 Progress: 53.87%	Loss: 0.5655
# Train Epoch 1 Progress: 54.4%	Loss: 0.7596
# Train Epoch 1 Progress: 54.93%	Loss: 1.2226
# Train Epoch 1 Progress: 55.47%	Loss: 0.7348
# Train Epoch 1 Progress: 56.0%	Loss: 0.5334
# Train Epoch 1 Progress: 56.53%	Loss: 0.6193
# Train Epoch 1 Progress: 57.07%	Loss: 0.4838
# Train Epoch 1 Progress: 57.6%	Loss: 0.6605
# Train Epoch 1 Progress: 58.13%	Loss: 0.5623
# Train Epoch 1 Progress: 58.67%	Loss: 0.8002
# Train Epoch 1 Progress: 59.2%	Loss: 0.5739
# Train Epoch 1 Progress: 59.73%	Loss: 0.316
# Train Epoch 1 Progress: 60.27%	Loss: 0.4769
# Train Epoch 1 Progress: 60.8%	Loss: 0.6706
# Train Epoch 1 Progress: 61.33%	Loss: 0.4261
# Train Epoch 1 Progress: 61.87%	Loss: 0.6953
# Train Epoch 1 Progress: 62.4%	Loss: 0.8059
# Train Epoch 1 Progress: 62.93%	Loss: 0.759
# Train Epoch 1 Progress: 63.47%	Loss: 0.8541
# Train Epoch 1 Progress: 64.0%	Loss: 0.6085
# Train Epoch 1 Progress: 64.53%	Loss: 1.0106
# Train Epoch 1 Progress: 65.07%	Loss: 0.6461
# Train Epoch 1 Progress: 65.6%	Loss: 0.6367
# Train Epoch 1 Progress: 66.13%	Loss: 0.4899
# Train Epoch 1 Progress: 66.67%	Loss: 0.7658
# Train Epoch 1 Progress: 67.2%	Loss: 0.3854
# Train Epoch 1 Progress: 67.73%	Loss: 0.5564
# Train Epoch 1 Progress: 68.27%	Loss: 0.4132
# Train Epoch 1 Progress: 68.8%	Loss: 0.6156
# Train Epoch 1 Progress: 69.33%	Loss: 0.7653
# Train Epoch 1 Progress: 69.87%	Loss: 0.6614
# Train Epoch 1 Progress: 70.4%	Loss: 0.4923
# Train Epoch 1 Progress: 70.93%	Loss: 0.886
# Train Epoch 1 Progress: 71.47%	Loss: 0.9578
# Train Epoch 1 Progress: 72.0%	Loss: 0.9954
# Train Epoch 1 Progress: 72.53%	Loss: 0.495
# Train Epoch 1 Progress: 73.07%	Loss: 0.6753
# Train Epoch 1 Progress: 73.6%	Loss: 0.4963
# Train Epoch 1 Progress: 74.13%	Loss: 0.5637
# Train Epoch 1 Progress: 74.67%	Loss: 0.8407
# Train Epoch 1 Progress: 75.2%	Loss: 0.8755
# Train Epoch 1 Progress: 75.73%	Loss: 0.6049
# Train Epoch 1 Progress: 76.27%	Loss: 0.8157
# Train Epoch 1 Progress: 76.8%	Loss: 0.6134
# Train Epoch 1 Progress: 77.33%	Loss: 0.524
# Train Epoch 1 Progress: 77.87%	Loss: 0.5341
# Train Epoch 1 Progress: 78.4%	Loss: 0.4781
# Train Epoch 1 Progress: 78.93%	Loss: 0.5592
# Train Epoch 1 Progress: 79.47%	Loss: 0.6673
# Train Epoch 1 Progress: 80.0%	Loss: 0.7327
# Train Epoch 1 Progress: 80.53%	Loss: 0.4918
# Train Epoch 1 Progress: 81.07%	Loss: 0.5672
# Train Epoch 1 Progress: 81.6%	Loss: 0.6725
# Train Epoch 1 Progress: 82.13%	Loss: 0.6582
# Train Epoch 1 Progress: 82.67%	Loss: 0.436
# Train Epoch 1 Progress: 83.2%	Loss: 0.4824
# Train Epoch 1 Progress: 83.73%	Loss: 0.4296
# Train Epoch 1 Progress: 84.27%	Loss: 0.6556
# Train Epoch 1 Progress: 84.8%	Loss: 0.9896
# Train Epoch 1 Progress: 85.33%	Loss: 0.4082
# Train Epoch 1 Progress: 85.87%	Loss: 0.6258
# Train Epoch 1 Progress: 86.4%	Loss: 0.6272
# Train Epoch 1 Progress: 86.93%	Loss: 0.7512
# Train Epoch 1 Progress: 87.47%	Loss: 0.5161
# Train Epoch 1 Progress: 88.0%	Loss: 0.5327
# Train Epoch 1 Progress: 88.53%	Loss: 0.7906
# Train Epoch 1 Progress: 89.07%	Loss: 0.4458
# Train Epoch 1 Progress: 89.6%	Loss: 0.6799
# Train Epoch 1 Progress: 90.13%	Loss: 0.3089
# Train Epoch 1 Progress: 90.67%	Loss: 0.525
# Train Epoch 1 Progress: 91.2%	Loss: 0.4354
# Train Epoch 1 Progress: 91.73%	Loss: 0.5462
# Train Epoch 1 Progress: 92.27%	Loss: 0.5964
# Train Epoch 1 Progress: 92.8%	Loss: 0.6526
# Train Epoch 1 Progress: 93.33%	Loss: 0.8883
# Train Epoch 1 Progress: 93.87%	Loss: 0.4859
# Train Epoch 1 Progress: 94.4%	Loss: 0.5768
# Train Epoch 1 Progress: 94.93%	Loss: 0.5593
# Train Epoch 1 Progress: 95.47%	Loss: 0.4572
# Train Epoch 1 Progress: 96.0%	Loss: 0.709
# Train Epoch 1 Progress: 96.53%	Loss: 0.5939
# Train Epoch 1 Progress: 97.07%	Loss: 0.5305
# Train Epoch 1 Progress: 97.6%	Loss: 0.8032
# Train Epoch 1 Progress: 98.13%	Loss: 0.728
# Train Epoch 1 Progress: 98.67%	Loss: 0.4441
# Train Epoch 1 Progress: 99.2%	Loss: 0.7473
# Train Epoch 1 Progress: 99.73%	Loss: 0.7311
#
# Test set: Avg loss 0.2903, Accuracy 91.61%
#
# Training with lr=0.001, momentum=0.5, batch_size=64
#
# Test set: Avg loss 2.3086, Accuracy 12.16%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3277
# Train Epoch 0 Progress: 1.07%	Loss: 2.3042
# Train Epoch 0 Progress: 2.13%	Loss: 2.3259
# Train Epoch 0 Progress: 3.2%	Loss: 2.3036
# Train Epoch 0 Progress: 4.27%	Loss: 2.2904
# Train Epoch 0 Progress: 5.33%	Loss: 2.3105
# Train Epoch 0 Progress: 6.4%	Loss: 2.3353
# Train Epoch 0 Progress: 7.47%	Loss: 2.2892
# Train Epoch 0 Progress: 8.53%	Loss: 2.311
# Train Epoch 0 Progress: 9.6%	Loss: 2.301
# Train Epoch 0 Progress: 10.67%	Loss: 2.3221
# Train Epoch 0 Progress: 11.73%	Loss: 2.278
# Train Epoch 0 Progress: 12.8%	Loss: 2.2908
# Train Epoch 0 Progress: 13.87%	Loss: 2.3126
# Train Epoch 0 Progress: 14.93%	Loss: 2.2872
# Train Epoch 0 Progress: 16.0%	Loss: 2.2883
# Train Epoch 0 Progress: 17.07%	Loss: 2.2977
# Train Epoch 0 Progress: 18.13%	Loss: 2.2956
# Train Epoch 0 Progress: 19.2%	Loss: 2.305
# Train Epoch 0 Progress: 20.27%	Loss: 2.2779
# Train Epoch 0 Progress: 21.33%	Loss: 2.2945
# Train Epoch 0 Progress: 22.4%	Loss: 2.289
# Train Epoch 0 Progress: 23.47%	Loss: 2.2646
# Train Epoch 0 Progress: 24.53%	Loss: 2.2831
# Train Epoch 0 Progress: 25.6%	Loss: 2.2864
# Train Epoch 0 Progress: 26.67%	Loss: 2.2591
# Train Epoch 0 Progress: 27.73%	Loss: 2.2978
# Train Epoch 0 Progress: 28.8%	Loss: 2.2732
# Train Epoch 0 Progress: 29.87%	Loss: 2.2789
# Train Epoch 0 Progress: 30.93%	Loss: 2.2861
# Train Epoch 0 Progress: 32.0%	Loss: 2.286
# Train Epoch 0 Progress: 33.07%	Loss: 2.2724
# Train Epoch 0 Progress: 34.13%	Loss: 2.2282
# Train Epoch 0 Progress: 35.2%	Loss: 2.2657
# Train Epoch 0 Progress: 36.27%	Loss: 2.2569
# Train Epoch 0 Progress: 37.33%	Loss: 2.2709
# Train Epoch 0 Progress: 38.4%	Loss: 2.2529
# Train Epoch 0 Progress: 39.47%	Loss: 2.2658
# Train Epoch 0 Progress: 40.53%	Loss: 2.275
# Train Epoch 0 Progress: 41.6%	Loss: 2.2326
# Train Epoch 0 Progress: 42.67%	Loss: 2.2505
# Train Epoch 0 Progress: 43.73%	Loss: 2.2662
# Train Epoch 0 Progress: 44.8%	Loss: 2.2413
# Train Epoch 0 Progress: 45.87%	Loss: 2.2451
# Train Epoch 0 Progress: 46.93%	Loss: 2.2588
# Train Epoch 0 Progress: 48.0%	Loss: 2.2096
# Train Epoch 0 Progress: 49.07%	Loss: 2.2074
# Train Epoch 0 Progress: 50.13%	Loss: 2.2797
# Train Epoch 0 Progress: 51.2%	Loss: 2.2144
# Train Epoch 0 Progress: 52.27%	Loss: 2.2087
# Train Epoch 0 Progress: 53.33%	Loss: 2.2365
# Train Epoch 0 Progress: 54.4%	Loss: 2.2359
# Train Epoch 0 Progress: 55.47%	Loss: 2.2354
# Train Epoch 0 Progress: 56.53%	Loss: 2.2272
# Train Epoch 0 Progress: 57.6%	Loss: 2.2164
# Train Epoch 0 Progress: 58.67%	Loss: 2.2646
# Train Epoch 0 Progress: 59.73%	Loss: 2.1742
# Train Epoch 0 Progress: 60.8%	Loss: 2.1833
# Train Epoch 0 Progress: 61.87%	Loss: 2.245
# Train Epoch 0 Progress: 62.93%	Loss: 2.1603
# Train Epoch 0 Progress: 64.0%	Loss: 2.156
# Train Epoch 0 Progress: 65.07%	Loss: 2.1797
# Train Epoch 0 Progress: 66.13%	Loss: 2.2232
# Train Epoch 0 Progress: 67.2%	Loss: 2.0931
# Train Epoch 0 Progress: 68.27%	Loss: 2.0802
# Train Epoch 0 Progress: 69.33%	Loss: 2.1894
# Train Epoch 0 Progress: 70.4%	Loss: 2.138
# Train Epoch 0 Progress: 71.47%	Loss: 2.1055
# Train Epoch 0 Progress: 72.53%	Loss: 2.1691
# Train Epoch 0 Progress: 73.6%	Loss: 2.2147
# Train Epoch 0 Progress: 74.67%	Loss: 2.1107
# Train Epoch 0 Progress: 75.73%	Loss: 2.146
# Train Epoch 0 Progress: 76.8%	Loss: 2.2082
# Train Epoch 0 Progress: 77.87%	Loss: 2.1035
# Train Epoch 0 Progress: 78.93%	Loss: 2.075
# Train Epoch 0 Progress: 80.0%	Loss: 2.1502
# Train Epoch 0 Progress: 81.07%	Loss: 2.0905
# Train Epoch 0 Progress: 82.13%	Loss: 2.1767
# Train Epoch 0 Progress: 83.2%	Loss: 2.1361
# Train Epoch 0 Progress: 84.27%	Loss: 2.1051
# Train Epoch 0 Progress: 85.33%	Loss: 2.1631
# Train Epoch 0 Progress: 86.4%	Loss: 2.0594
# Train Epoch 0 Progress: 87.47%	Loss: 2.0156
# Train Epoch 0 Progress: 88.53%	Loss: 2.0267
# Train Epoch 0 Progress: 89.6%	Loss: 2.0741
# Train Epoch 0 Progress: 90.67%	Loss: 2.0968
# Train Epoch 0 Progress: 91.73%	Loss: 1.9365
# Train Epoch 0 Progress: 92.8%	Loss: 1.9942
# Train Epoch 0 Progress: 93.87%	Loss: 2.0359
# Train Epoch 0 Progress: 94.93%	Loss: 2.0108
# Train Epoch 0 Progress: 96.0%	Loss: 1.9391
# Train Epoch 0 Progress: 97.07%	Loss: 1.8958
# Train Epoch 0 Progress: 98.13%	Loss: 1.9327
# Train Epoch 0 Progress: 99.2%	Loss: 1.8498
#
# Test set: Avg loss 1.8539, Accuracy 56.67%
#
# Train Epoch 1 Progress: 0.0%	Loss: 1.9284
# Train Epoch 1 Progress: 1.07%	Loss: 1.9682
# Train Epoch 1 Progress: 2.13%	Loss: 1.9738
# Train Epoch 1 Progress: 3.2%	Loss: 1.9967
# Train Epoch 1 Progress: 4.27%	Loss: 1.9659
# Train Epoch 1 Progress: 5.33%	Loss: 1.9145
# Train Epoch 1 Progress: 6.4%	Loss: 1.8857
# Train Epoch 1 Progress: 7.47%	Loss: 1.9286
# Train Epoch 1 Progress: 8.53%	Loss: 1.9034
# Train Epoch 1 Progress: 9.6%	Loss: 1.7603
# Train Epoch 1 Progress: 10.67%	Loss: 1.7321
# Train Epoch 1 Progress: 11.73%	Loss: 1.8038
# Train Epoch 1 Progress: 12.8%	Loss: 1.8764
# Train Epoch 1 Progress: 13.87%	Loss: 1.8642
# Train Epoch 1 Progress: 14.93%	Loss: 1.6842
# Train Epoch 1 Progress: 16.0%	Loss: 1.6009
# Train Epoch 1 Progress: 17.07%	Loss: 1.7187
# Train Epoch 1 Progress: 18.13%	Loss: 1.8955
# Train Epoch 1 Progress: 19.2%	Loss: 1.6298
# Train Epoch 1 Progress: 20.27%	Loss: 1.8544
# Train Epoch 1 Progress: 21.33%	Loss: 1.7318
# Train Epoch 1 Progress: 22.4%	Loss: 1.7689
# Train Epoch 1 Progress: 23.47%	Loss: 1.6337
# Train Epoch 1 Progress: 24.53%	Loss: 1.7913
# Train Epoch 1 Progress: 25.6%	Loss: 1.7645
# Train Epoch 1 Progress: 26.67%	Loss: 1.4218
# Train Epoch 1 Progress: 27.73%	Loss: 1.7403
# Train Epoch 1 Progress: 28.8%	Loss: 1.6308
# Train Epoch 1 Progress: 29.87%	Loss: 1.548
# Train Epoch 1 Progress: 30.93%	Loss: 1.7059
# Train Epoch 1 Progress: 32.0%	Loss: 1.659
# Train Epoch 1 Progress: 33.07%	Loss: 1.5617
# Train Epoch 1 Progress: 34.13%	Loss: 1.6235
# Train Epoch 1 Progress: 35.2%	Loss: 1.5126
# Train Epoch 1 Progress: 36.27%	Loss: 1.5094
# Train Epoch 1 Progress: 37.33%	Loss: 1.6067
# Train Epoch 1 Progress: 38.4%	Loss: 1.5015
# Train Epoch 1 Progress: 39.47%	Loss: 1.663
# Train Epoch 1 Progress: 40.53%	Loss: 1.4907
# Train Epoch 1 Progress: 41.6%	Loss: 1.5802
# Train Epoch 1 Progress: 42.67%	Loss: 1.7065
# Train Epoch 1 Progress: 43.73%	Loss: 1.5183
# Train Epoch 1 Progress: 44.8%	Loss: 1.4545
# Train Epoch 1 Progress: 45.87%	Loss: 1.509
# Train Epoch 1 Progress: 46.93%	Loss: 1.4178
# Train Epoch 1 Progress: 48.0%	Loss: 1.3304
# Train Epoch 1 Progress: 49.07%	Loss: 1.2237
# Train Epoch 1 Progress: 50.13%	Loss: 1.5076
# Train Epoch 1 Progress: 51.2%	Loss: 1.4045
# Train Epoch 1 Progress: 52.27%	Loss: 1.721
# Train Epoch 1 Progress: 53.33%	Loss: 1.4665
# Train Epoch 1 Progress: 54.4%	Loss: 1.5881
# Train Epoch 1 Progress: 55.47%	Loss: 1.3727
# Train Epoch 1 Progress: 56.53%	Loss: 1.4891
# Train Epoch 1 Progress: 57.6%	Loss: 1.298
# Train Epoch 1 Progress: 58.67%	Loss: 1.4142
# Train Epoch 1 Progress: 59.73%	Loss: 1.1947
# Train Epoch 1 Progress: 60.8%	Loss: 1.3339
# Train Epoch 1 Progress: 61.87%	Loss: 1.4153
# Train Epoch 1 Progress: 62.93%	Loss: 1.2904
# Train Epoch 1 Progress: 64.0%	Loss: 1.427
# Train Epoch 1 Progress: 65.07%	Loss: 1.3174
# Train Epoch 1 Progress: 66.13%	Loss: 1.3505
# Train Epoch 1 Progress: 67.2%	Loss: 1.3143
# Train Epoch 1 Progress: 68.27%	Loss: 1.3739
# Train Epoch 1 Progress: 69.33%	Loss: 1.1512
# Train Epoch 1 Progress: 70.4%	Loss: 1.1257
# Train Epoch 1 Progress: 71.47%	Loss: 1.2879
# Train Epoch 1 Progress: 72.53%	Loss: 1.1208
# Train Epoch 1 Progress: 73.6%	Loss: 1.2137
# Train Epoch 1 Progress: 74.67%	Loss: 1.0079
# Train Epoch 1 Progress: 75.73%	Loss: 1.2165
# Train Epoch 1 Progress: 76.8%	Loss: 1.1312
# Train Epoch 1 Progress: 77.87%	Loss: 1.2532
# Train Epoch 1 Progress: 78.93%	Loss: 1.1135
# Train Epoch 1 Progress: 80.0%	Loss: 1.0532
# Train Epoch 1 Progress: 81.07%	Loss: 1.0836
# Train Epoch 1 Progress: 82.13%	Loss: 1.0998
# Train Epoch 1 Progress: 83.2%	Loss: 1.1693
# Train Epoch 1 Progress: 84.27%	Loss: 1.2692
# Train Epoch 1 Progress: 85.33%	Loss: 1.3022
# Train Epoch 1 Progress: 86.4%	Loss: 1.089
# Train Epoch 1 Progress: 87.47%	Loss: 0.9802
# Train Epoch 1 Progress: 88.53%	Loss: 1.0793
# Train Epoch 1 Progress: 89.6%	Loss: 1.1542
# Train Epoch 1 Progress: 90.67%	Loss: 1.0156
# Train Epoch 1 Progress: 91.73%	Loss: 1.0892
# Train Epoch 1 Progress: 92.8%	Loss: 0.93
# Train Epoch 1 Progress: 93.87%	Loss: 0.984
# Train Epoch 1 Progress: 94.93%	Loss: 0.9894
# Train Epoch 1 Progress: 96.0%	Loss: 1.1924
# Train Epoch 1 Progress: 97.07%	Loss: 1.0964
# Train Epoch 1 Progress: 98.13%	Loss: 0.9664
# Train Epoch 1 Progress: 99.2%	Loss: 1.1406
#
# Test set: Avg loss 0.6945, Accuracy 85.09%
#
# Training with lr=0.001, momentum=0.5, batch_size=128
#
# Test set: Avg loss 2.3102, Accuracy 10.32%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.351
# Train Epoch 0 Progress: 2.13%	Loss: 2.2799
# Train Epoch 0 Progress: 4.27%	Loss: 2.3163
# Train Epoch 0 Progress: 6.4%	Loss: 2.3271
# Train Epoch 0 Progress: 8.53%	Loss: 2.3239
# Train Epoch 0 Progress: 10.67%	Loss: 2.285
# Train Epoch 0 Progress: 12.8%	Loss: 2.3455
# Train Epoch 0 Progress: 14.93%	Loss: 2.2867
# Train Epoch 0 Progress: 17.07%	Loss: 2.305
# Train Epoch 0 Progress: 19.2%	Loss: 2.2849
# Train Epoch 0 Progress: 21.33%	Loss: 2.3135
# Train Epoch 0 Progress: 23.47%	Loss: 2.2962
# Train Epoch 0 Progress: 25.6%	Loss: 2.3307
# Train Epoch 0 Progress: 27.73%	Loss: 2.281
# Train Epoch 0 Progress: 29.87%	Loss: 2.2756
# Train Epoch 0 Progress: 32.0%	Loss: 2.3289
# Train Epoch 0 Progress: 34.13%	Loss: 2.301
# Train Epoch 0 Progress: 36.27%	Loss: 2.2872
# Train Epoch 0 Progress: 38.4%	Loss: 2.3166
# Train Epoch 0 Progress: 40.53%	Loss: 2.2822
# Train Epoch 0 Progress: 42.67%	Loss: 2.276
# Train Epoch 0 Progress: 44.8%	Loss: 2.2948
# Train Epoch 0 Progress: 46.93%	Loss: 2.267
# Train Epoch 0 Progress: 49.07%	Loss: 2.2674
# Train Epoch 0 Progress: 51.2%	Loss: 2.2957
# Train Epoch 0 Progress: 53.33%	Loss: 2.2909
# Train Epoch 0 Progress: 55.47%	Loss: 2.2883
# Train Epoch 0 Progress: 57.6%	Loss: 2.2513
# Train Epoch 0 Progress: 59.73%	Loss: 2.2605
# Train Epoch 0 Progress: 61.87%	Loss: 2.2772
# Train Epoch 0 Progress: 64.0%	Loss: 2.2884
# Train Epoch 0 Progress: 66.13%	Loss: 2.2692
# Train Epoch 0 Progress: 68.27%	Loss: 2.2717
# Train Epoch 0 Progress: 70.4%	Loss: 2.2666
# Train Epoch 0 Progress: 72.53%	Loss: 2.2753
# Train Epoch 0 Progress: 74.67%	Loss: 2.2618
# Train Epoch 0 Progress: 76.8%	Loss: 2.2511
# Train Epoch 0 Progress: 78.93%	Loss: 2.2355
# Train Epoch 0 Progress: 81.07%	Loss: 2.2724
# Train Epoch 0 Progress: 83.2%	Loss: 2.2658
# Train Epoch 0 Progress: 85.33%	Loss: 2.2501
# Train Epoch 0 Progress: 87.47%	Loss: 2.2412
# Train Epoch 0 Progress: 89.6%	Loss: 2.2428
# Train Epoch 0 Progress: 91.73%	Loss: 2.2489
# Train Epoch 0 Progress: 93.87%	Loss: 2.2382
# Train Epoch 0 Progress: 96.0%	Loss: 2.2314
# Train Epoch 0 Progress: 98.13%	Loss: 2.2149
#
# Test set: Avg loss 2.2172, Accuracy 37.09%
#
# Train Epoch 1 Progress: 0.0%	Loss: 2.226
# Train Epoch 1 Progress: 2.13%	Loss: 2.2369
# Train Epoch 1 Progress: 4.27%	Loss: 2.228
# Train Epoch 1 Progress: 6.4%	Loss: 2.2161
# Train Epoch 1 Progress: 8.53%	Loss: 2.2123
# Train Epoch 1 Progress: 10.67%	Loss: 2.2465
# Train Epoch 1 Progress: 12.8%	Loss: 2.2337
# Train Epoch 1 Progress: 14.93%	Loss: 2.2329
# Train Epoch 1 Progress: 17.07%	Loss: 2.1949
# Train Epoch 1 Progress: 19.2%	Loss: 2.2031
# Train Epoch 1 Progress: 21.33%	Loss: 2.2142
# Train Epoch 1 Progress: 23.47%	Loss: 2.2057
# Train Epoch 1 Progress: 25.6%	Loss: 2.2056
# Train Epoch 1 Progress: 27.73%	Loss: 2.2013
# Train Epoch 1 Progress: 29.87%	Loss: 2.2174
# Train Epoch 1 Progress: 32.0%	Loss: 2.1792
# Train Epoch 1 Progress: 34.13%	Loss: 2.1464
# Train Epoch 1 Progress: 36.27%	Loss: 2.1637
# Train Epoch 1 Progress: 38.4%	Loss: 2.1458
# Train Epoch 1 Progress: 40.53%	Loss: 2.1431
# Train Epoch 1 Progress: 42.67%	Loss: 2.1963
# Train Epoch 1 Progress: 44.8%	Loss: 2.1705
# Train Epoch 1 Progress: 46.93%	Loss: 2.1711
# Train Epoch 1 Progress: 49.07%	Loss: 2.1428
# Train Epoch 1 Progress: 51.2%	Loss: 2.1464
# Train Epoch 1 Progress: 53.33%	Loss: 2.1335
# Train Epoch 1 Progress: 55.47%	Loss: 2.1321
# Train Epoch 1 Progress: 57.6%	Loss: 2.1525
# Train Epoch 1 Progress: 59.73%	Loss: 2.1711
# Train Epoch 1 Progress: 61.87%	Loss: 2.1361
# Train Epoch 1 Progress: 64.0%	Loss: 2.1417
# Train Epoch 1 Progress: 66.13%	Loss: 2.139
# Train Epoch 1 Progress: 68.27%	Loss: 2.0778
# Train Epoch 1 Progress: 70.4%	Loss: 2.0765
# Train Epoch 1 Progress: 72.53%	Loss: 2.0937
# Train Epoch 1 Progress: 74.67%	Loss: 2.0992
# Train Epoch 1 Progress: 76.8%	Loss: 2.0203
# Train Epoch 1 Progress: 78.93%	Loss: 2.0953
# Train Epoch 1 Progress: 81.07%	Loss: 2.0399
# Train Epoch 1 Progress: 83.2%	Loss: 2.0659
# Train Epoch 1 Progress: 85.33%	Loss: 2.0073
# Train Epoch 1 Progress: 87.47%	Loss: 2.0937
# Train Epoch 1 Progress: 89.6%	Loss: 2.0351
# Train Epoch 1 Progress: 91.73%	Loss: 1.9748
# Train Epoch 1 Progress: 93.87%	Loss: 2.033
# Train Epoch 1 Progress: 96.0%	Loss: 2.0117
# Train Epoch 1 Progress: 98.13%	Loss: 2.0302
#
# Test set: Avg loss 1.8896, Accuracy 53.84%
#
# Training with lr=0.001, momentum=0.9, batch_size=32
#
# Test set: Avg loss 2.3091, Accuracy 9.18%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3471
# Train Epoch 0 Progress: 0.53%	Loss: 2.286
# Train Epoch 0 Progress: 1.07%	Loss: 2.2972
# Train Epoch 0 Progress: 1.6%	Loss: 2.326
# Train Epoch 0 Progress: 2.13%	Loss: 2.3295
# Train Epoch 0 Progress: 2.67%	Loss: 2.2695
# Train Epoch 0 Progress: 3.2%	Loss: 2.2832
# Train Epoch 0 Progress: 3.73%	Loss: 2.2579
# Train Epoch 0 Progress: 4.27%	Loss: 2.2469
# Train Epoch 0 Progress: 4.8%	Loss: 2.2436
# Train Epoch 0 Progress: 5.33%	Loss: 2.2023
# Train Epoch 0 Progress: 5.87%	Loss: 2.2909
# Train Epoch 0 Progress: 6.4%	Loss: 2.1536
# Train Epoch 0 Progress: 6.93%	Loss: 2.1303
# Train Epoch 0 Progress: 7.47%	Loss: 2.1741
# Train Epoch 0 Progress: 8.0%	Loss: 2.1942
# Train Epoch 0 Progress: 8.53%	Loss: 2.1082
# Train Epoch 0 Progress: 9.07%	Loss: 2.1489
# Train Epoch 0 Progress: 9.6%	Loss: 2.122
# Train Epoch 0 Progress: 10.13%	Loss: 2.1181
# Train Epoch 0 Progress: 10.67%	Loss: 1.9894
# Train Epoch 0 Progress: 11.2%	Loss: 1.8622
# Train Epoch 0 Progress: 11.73%	Loss: 2.0491
# Train Epoch 0 Progress: 12.27%	Loss: 1.9762
# Train Epoch 0 Progress: 12.8%	Loss: 1.8266
# Train Epoch 0 Progress: 13.33%	Loss: 1.7603
# Train Epoch 0 Progress: 13.87%	Loss: 1.5784
# Train Epoch 0 Progress: 14.4%	Loss: 1.8681
# Train Epoch 0 Progress: 14.93%	Loss: 1.6553
# Train Epoch 0 Progress: 15.47%	Loss: 1.6132
# Train Epoch 0 Progress: 16.0%	Loss: 1.6448
# Train Epoch 0 Progress: 16.53%	Loss: 1.6464
# Train Epoch 0 Progress: 17.07%	Loss: 1.3198
# Train Epoch 0 Progress: 17.6%	Loss: 1.6783
# Train Epoch 0 Progress: 18.13%	Loss: 1.477
# Train Epoch 0 Progress: 18.67%	Loss: 1.4181
# Train Epoch 0 Progress: 19.2%	Loss: 1.3791
# Train Epoch 0 Progress: 19.73%	Loss: 1.343
# Train Epoch 0 Progress: 20.27%	Loss: 1.2578
# Train Epoch 0 Progress: 20.8%	Loss: 1.1958
# Train Epoch 0 Progress: 21.33%	Loss: 1.3262
# Train Epoch 0 Progress: 21.87%	Loss: 1.3299
# Train Epoch 0 Progress: 22.4%	Loss: 1.5731
# Train Epoch 0 Progress: 22.93%	Loss: 1.2909
# Train Epoch 0 Progress: 23.47%	Loss: 1.1196
# Train Epoch 0 Progress: 24.0%	Loss: 0.9394
# Train Epoch 0 Progress: 24.53%	Loss: 0.901
# Train Epoch 0 Progress: 25.07%	Loss: 1.0755
# Train Epoch 0 Progress: 25.6%	Loss: 0.9823
# Train Epoch 0 Progress: 26.13%	Loss: 1.7152
# Train Epoch 0 Progress: 26.67%	Loss: 1.0426
# Train Epoch 0 Progress: 27.2%	Loss: 1.1472
# Train Epoch 0 Progress: 27.73%	Loss: 1.4303
# Train Epoch 0 Progress: 28.27%	Loss: 1.3023
# Train Epoch 0 Progress: 28.8%	Loss: 0.7678
# Train Epoch 0 Progress: 29.33%	Loss: 0.9897
# Train Epoch 0 Progress: 29.87%	Loss: 0.9231
# Train Epoch 0 Progress: 30.4%	Loss: 0.9956
# Train Epoch 0 Progress: 30.93%	Loss: 0.9868
# Train Epoch 0 Progress: 31.47%	Loss: 0.7256
# Train Epoch 0 Progress: 32.0%	Loss: 1.3131
# Train Epoch 0 Progress: 32.53%	Loss: 0.8084
# Train Epoch 0 Progress: 33.07%	Loss: 1.0909
# Train Epoch 0 Progress: 33.6%	Loss: 0.7378
# Train Epoch 0 Progress: 34.13%	Loss: 0.7491
# Train Epoch 0 Progress: 34.67%	Loss: 1.2009
# Train Epoch 0 Progress: 35.2%	Loss: 1.1274
# Train Epoch 0 Progress: 35.73%	Loss: 1.4549
# Train Epoch 0 Progress: 36.27%	Loss: 0.7863
# Train Epoch 0 Progress: 36.8%	Loss: 0.6616
# Train Epoch 0 Progress: 37.33%	Loss: 0.9328
# Train Epoch 0 Progress: 37.87%	Loss: 1.0298
# Train Epoch 0 Progress: 38.4%	Loss: 0.8609
# Train Epoch 0 Progress: 38.93%	Loss: 1.3443
# Train Epoch 0 Progress: 39.47%	Loss: 0.662
# Train Epoch 0 Progress: 40.0%	Loss: 0.6783
# Train Epoch 0 Progress: 40.53%	Loss: 1.2133
# Train Epoch 0 Progress: 41.07%	Loss: 1.1412
# Train Epoch 0 Progress: 41.6%	Loss: 1.0285
# Train Epoch 0 Progress: 42.13%	Loss: 0.8843
# Train Epoch 0 Progress: 42.67%	Loss: 0.6448
# Train Epoch 0 Progress: 43.2%	Loss: 1.0611
# Train Epoch 0 Progress: 43.73%	Loss: 0.7496
# Train Epoch 0 Progress: 44.27%	Loss: 1.1909
# Train Epoch 0 Progress: 44.8%	Loss: 0.7967
# Train Epoch 0 Progress: 45.33%	Loss: 1.0947
# Train Epoch 0 Progress: 45.87%	Loss: 0.7835
# Train Epoch 0 Progress: 46.4%	Loss: 1.1055
# Train Epoch 0 Progress: 46.93%	Loss: 0.6616
# Train Epoch 0 Progress: 47.47%	Loss: 0.8678
# Train Epoch 0 Progress: 48.0%	Loss: 0.5672
# Train Epoch 0 Progress: 48.53%	Loss: 0.6399
# Train Epoch 0 Progress: 49.07%	Loss: 0.6446
# Train Epoch 0 Progress: 49.6%	Loss: 0.5257
# Train Epoch 0 Progress: 50.13%	Loss: 0.6133
# Train Epoch 0 Progress: 50.67%	Loss: 1.0384
# Train Epoch 0 Progress: 51.2%	Loss: 0.8323
# Train Epoch 0 Progress: 51.73%	Loss: 0.5001
# Train Epoch 0 Progress: 52.27%	Loss: 1.0509
# Train Epoch 0 Progress: 52.8%	Loss: 0.8007
# Train Epoch 0 Progress: 53.33%	Loss: 0.5312
# Train Epoch 0 Progress: 53.87%	Loss: 0.583
# Train Epoch 0 Progress: 54.4%	Loss: 0.6798
# Train Epoch 0 Progress: 54.93%	Loss: 0.6429
# Train Epoch 0 Progress: 55.47%	Loss: 0.764
# Train Epoch 0 Progress: 56.0%	Loss: 0.7356
# Train Epoch 0 Progress: 56.53%	Loss: 0.7481
# Train Epoch 0 Progress: 57.07%	Loss: 0.5049
# Train Epoch 0 Progress: 57.6%	Loss: 0.7688
# Train Epoch 0 Progress: 58.13%	Loss: 0.9399
# Train Epoch 0 Progress: 58.67%	Loss: 0.7731
# Train Epoch 0 Progress: 59.2%	Loss: 0.8185
# Train Epoch 0 Progress: 59.73%	Loss: 0.8101
# Train Epoch 0 Progress: 60.27%	Loss: 0.3546
# Train Epoch 0 Progress: 60.8%	Loss: 0.6467
# Train Epoch 0 Progress: 61.33%	Loss: 0.6656
# Train Epoch 0 Progress: 61.87%	Loss: 0.5672
# Train Epoch 0 Progress: 62.4%	Loss: 0.596
# Train Epoch 0 Progress: 62.93%	Loss: 0.3917
# Train Epoch 0 Progress: 63.47%	Loss: 0.6222
# Train Epoch 0 Progress: 64.0%	Loss: 0.4909
# Train Epoch 0 Progress: 64.53%	Loss: 1.0282
# Train Epoch 0 Progress: 65.07%	Loss: 0.6918
# Train Epoch 0 Progress: 65.6%	Loss: 0.5665
# Train Epoch 0 Progress: 66.13%	Loss: 0.4914
# Train Epoch 0 Progress: 66.67%	Loss: 0.5413
# Train Epoch 0 Progress: 67.2%	Loss: 0.7273
# Train Epoch 0 Progress: 67.73%	Loss: 0.3483
# Train Epoch 0 Progress: 68.27%	Loss: 0.6512
# Train Epoch 0 Progress: 68.8%	Loss: 0.346
# Train Epoch 0 Progress: 69.33%	Loss: 0.6925
# Train Epoch 0 Progress: 69.87%	Loss: 0.3102
# Train Epoch 0 Progress: 70.4%	Loss: 0.4732
# Train Epoch 0 Progress: 70.93%	Loss: 0.6908
# Train Epoch 0 Progress: 71.47%	Loss: 0.4557
# Train Epoch 0 Progress: 72.0%	Loss: 0.7395
# Train Epoch 0 Progress: 72.53%	Loss: 0.5574
# Train Epoch 0 Progress: 73.07%	Loss: 0.9799
# Train Epoch 0 Progress: 73.6%	Loss: 0.6477
# Train Epoch 0 Progress: 74.13%	Loss: 0.4752
# Train Epoch 0 Progress: 74.67%	Loss: 0.725
# Train Epoch 0 Progress: 75.2%	Loss: 0.5474
# Train Epoch 0 Progress: 75.73%	Loss: 0.6218
# Train Epoch 0 Progress: 76.27%	Loss: 0.7494
# Train Epoch 0 Progress: 76.8%	Loss: 0.5727
# Train Epoch 0 Progress: 77.33%	Loss: 0.5798
# Train Epoch 0 Progress: 77.87%	Loss: 0.4116
# Train Epoch 0 Progress: 78.4%	Loss: 0.3119
# Train Epoch 0 Progress: 78.93%	Loss: 1.0936
# Train Epoch 0 Progress: 79.47%	Loss: 0.481
# Train Epoch 0 Progress: 80.0%	Loss: 0.344
# Train Epoch 0 Progress: 80.53%	Loss: 0.4804
# Train Epoch 0 Progress: 81.07%	Loss: 0.3863
# Train Epoch 0 Progress: 81.6%	Loss: 0.3657
# Train Epoch 0 Progress: 82.13%	Loss: 0.3927
# Train Epoch 0 Progress: 82.67%	Loss: 0.6416
# Train Epoch 0 Progress: 83.2%	Loss: 0.336
# Train Epoch 0 Progress: 83.73%	Loss: 0.327
# Train Epoch 0 Progress: 84.27%	Loss: 0.426
# Train Epoch 0 Progress: 84.8%	Loss: 0.4037
# Train Epoch 0 Progress: 85.33%	Loss: 0.6175
# Train Epoch 0 Progress: 85.87%	Loss: 0.629
# Train Epoch 0 Progress: 86.4%	Loss: 0.3855
# Train Epoch 0 Progress: 86.93%	Loss: 0.4252
# Train Epoch 0 Progress: 87.47%	Loss: 0.5724
# Train Epoch 0 Progress: 88.0%	Loss: 0.3126
# Train Epoch 0 Progress: 88.53%	Loss: 0.597
# Train Epoch 0 Progress: 89.07%	Loss: 0.6035
# Train Epoch 0 Progress: 89.6%	Loss: 0.5295
# Train Epoch 0 Progress: 90.13%	Loss: 0.3087
# Train Epoch 0 Progress: 90.67%	Loss: 0.5481
# Train Epoch 0 Progress: 91.2%	Loss: 0.5597
# Train Epoch 0 Progress: 91.73%	Loss: 0.6213
# Train Epoch 0 Progress: 92.27%	Loss: 0.5108
# Train Epoch 0 Progress: 92.8%	Loss: 0.4869
# Train Epoch 0 Progress: 93.33%	Loss: 0.6604
# Train Epoch 0 Progress: 93.87%	Loss: 1.3
# Train Epoch 0 Progress: 94.4%	Loss: 0.4273
# Train Epoch 0 Progress: 94.93%	Loss: 0.224
# Train Epoch 0 Progress: 95.47%	Loss: 0.439
# Train Epoch 0 Progress: 96.0%	Loss: 0.6115
# Train Epoch 0 Progress: 96.53%	Loss: 0.2255
# Train Epoch 0 Progress: 97.07%	Loss: 0.6691
# Train Epoch 0 Progress: 97.6%	Loss: 0.4222
# Train Epoch 0 Progress: 98.13%	Loss: 0.3996
# Train Epoch 0 Progress: 98.67%	Loss: 0.4747
# Train Epoch 0 Progress: 99.2%	Loss: 0.4107
# Train Epoch 0 Progress: 99.73%	Loss: 0.4275
#
# Test set: Avg loss 0.1927, Accuracy 94.49%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.602
# Train Epoch 1 Progress: 0.53%	Loss: 0.5425
# Train Epoch 1 Progress: 1.07%	Loss: 0.6354
# Train Epoch 1 Progress: 1.6%	Loss: 0.5004
# Train Epoch 1 Progress: 2.13%	Loss: 0.7922
# Train Epoch 1 Progress: 2.67%	Loss: 0.4211
# Train Epoch 1 Progress: 3.2%	Loss: 0.2474
# Train Epoch 1 Progress: 3.73%	Loss: 0.3056
# Train Epoch 1 Progress: 4.27%	Loss: 0.2987
# Train Epoch 1 Progress: 4.8%	Loss: 0.511
# Train Epoch 1 Progress: 5.33%	Loss: 0.7883
# Train Epoch 1 Progress: 5.87%	Loss: 0.4445
# Train Epoch 1 Progress: 6.4%	Loss: 0.3192
# Train Epoch 1 Progress: 6.93%	Loss: 0.2778
# Train Epoch 1 Progress: 7.47%	Loss: 1.1569
# Train Epoch 1 Progress: 8.0%	Loss: 0.5787
# Train Epoch 1 Progress: 8.53%	Loss: 0.5606
# Train Epoch 1 Progress: 9.07%	Loss: 0.2487
# Train Epoch 1 Progress: 9.6%	Loss: 0.6788
# Train Epoch 1 Progress: 10.13%	Loss: 0.375
# Train Epoch 1 Progress: 10.67%	Loss: 0.6678
# Train Epoch 1 Progress: 11.2%	Loss: 0.4371
# Train Epoch 1 Progress: 11.73%	Loss: 0.9215
# Train Epoch 1 Progress: 12.27%	Loss: 1.2595
# Train Epoch 1 Progress: 12.8%	Loss: 0.6355
# Train Epoch 1 Progress: 13.33%	Loss: 0.2944
# Train Epoch 1 Progress: 13.87%	Loss: 0.6075
# Train Epoch 1 Progress: 14.4%	Loss: 0.5478
# Train Epoch 1 Progress: 14.93%	Loss: 0.5808
# Train Epoch 1 Progress: 15.47%	Loss: 0.4484
# Train Epoch 1 Progress: 16.0%	Loss: 0.4908
# Train Epoch 1 Progress: 16.53%	Loss: 0.4878
# Train Epoch 1 Progress: 17.07%	Loss: 0.4226
# Train Epoch 1 Progress: 17.6%	Loss: 0.5682
# Train Epoch 1 Progress: 18.13%	Loss: 0.2377
# Train Epoch 1 Progress: 18.67%	Loss: 0.623
# Train Epoch 1 Progress: 19.2%	Loss: 0.3343
# Train Epoch 1 Progress: 19.73%	Loss: 0.2366
# Train Epoch 1 Progress: 20.27%	Loss: 0.3948
# Train Epoch 1 Progress: 20.8%	Loss: 0.4759
# Train Epoch 1 Progress: 21.33%	Loss: 0.5816
# Train Epoch 1 Progress: 21.87%	Loss: 0.3299
# Train Epoch 1 Progress: 22.4%	Loss: 0.2809
# Train Epoch 1 Progress: 22.93%	Loss: 0.3463
# Train Epoch 1 Progress: 23.47%	Loss: 0.4071
# Train Epoch 1 Progress: 24.0%	Loss: 0.5126
# Train Epoch 1 Progress: 24.53%	Loss: 0.2095
# Train Epoch 1 Progress: 25.07%	Loss: 0.2561
# Train Epoch 1 Progress: 25.6%	Loss: 0.6693
# Train Epoch 1 Progress: 26.13%	Loss: 0.7019
# Train Epoch 1 Progress: 26.67%	Loss: 0.5604
# Train Epoch 1 Progress: 27.2%	Loss: 0.289
# Train Epoch 1 Progress: 27.73%	Loss: 0.6856
# Train Epoch 1 Progress: 28.27%	Loss: 0.4143
# Train Epoch 1 Progress: 28.8%	Loss: 0.3571
# Train Epoch 1 Progress: 29.33%	Loss: 0.3123
# Train Epoch 1 Progress: 29.87%	Loss: 0.473
# Train Epoch 1 Progress: 30.4%	Loss: 0.3194
# Train Epoch 1 Progress: 30.93%	Loss: 0.4558
# Train Epoch 1 Progress: 31.47%	Loss: 0.3343
# Train Epoch 1 Progress: 32.0%	Loss: 0.4783
# Train Epoch 1 Progress: 32.53%	Loss: 0.2553
# Train Epoch 1 Progress: 33.07%	Loss: 0.48
# Train Epoch 1 Progress: 33.6%	Loss: 0.1243
# Train Epoch 1 Progress: 34.13%	Loss: 0.3592
# Train Epoch 1 Progress: 34.67%	Loss: 0.5386
# Train Epoch 1 Progress: 35.2%	Loss: 0.3786
# Train Epoch 1 Progress: 35.73%	Loss: 0.3653
# Train Epoch 1 Progress: 36.27%	Loss: 0.4152
# Train Epoch 1 Progress: 36.8%	Loss: 0.3522
# Train Epoch 1 Progress: 37.33%	Loss: 0.1701
# Train Epoch 1 Progress: 37.87%	Loss: 0.2646
# Train Epoch 1 Progress: 38.4%	Loss: 0.3599
# Train Epoch 1 Progress: 38.93%	Loss: 0.3769
# Train Epoch 1 Progress: 39.47%	Loss: 0.3825
# Train Epoch 1 Progress: 40.0%	Loss: 0.4512
# Train Epoch 1 Progress: 40.53%	Loss: 0.339
# Train Epoch 1 Progress: 41.07%	Loss: 0.1961
# Train Epoch 1 Progress: 41.6%	Loss: 0.2473
# Train Epoch 1 Progress: 42.13%	Loss: 0.2671
# Train Epoch 1 Progress: 42.67%	Loss: 0.3123
# Train Epoch 1 Progress: 43.2%	Loss: 0.3662
# Train Epoch 1 Progress: 43.73%	Loss: 0.4573
# Train Epoch 1 Progress: 44.27%	Loss: 0.3615
# Train Epoch 1 Progress: 44.8%	Loss: 0.5047
# Train Epoch 1 Progress: 45.33%	Loss: 0.2913
# Train Epoch 1 Progress: 45.87%	Loss: 0.2561
# Train Epoch 1 Progress: 46.4%	Loss: 0.3908
# Train Epoch 1 Progress: 46.93%	Loss: 0.8193
# Train Epoch 1 Progress: 47.47%	Loss: 0.3605
# Train Epoch 1 Progress: 48.0%	Loss: 0.8863
# Train Epoch 1 Progress: 48.53%	Loss: 0.3506
# Train Epoch 1 Progress: 49.07%	Loss: 0.8056
# Train Epoch 1 Progress: 49.6%	Loss: 0.3964
# Train Epoch 1 Progress: 50.13%	Loss: 0.4006
# Train Epoch 1 Progress: 50.67%	Loss: 0.3069
# Train Epoch 1 Progress: 51.2%	Loss: 0.3485
# Train Epoch 1 Progress: 51.73%	Loss: 0.2955
# Train Epoch 1 Progress: 52.27%	Loss: 0.4203
# Train Epoch 1 Progress: 52.8%	Loss: 0.2011
# Train Epoch 1 Progress: 53.33%	Loss: 0.3073
# Train Epoch 1 Progress: 53.87%	Loss: 0.2307
# Train Epoch 1 Progress: 54.4%	Loss: 0.1934
# Train Epoch 1 Progress: 54.93%	Loss: 0.3925
# Train Epoch 1 Progress: 55.47%	Loss: 0.3139
# Train Epoch 1 Progress: 56.0%	Loss: 0.3659
# Train Epoch 1 Progress: 56.53%	Loss: 0.5572
# Train Epoch 1 Progress: 57.07%	Loss: 0.6843
# Train Epoch 1 Progress: 57.6%	Loss: 0.1642
# Train Epoch 1 Progress: 58.13%	Loss: 0.1197
# Train Epoch 1 Progress: 58.67%	Loss: 0.3823
# Train Epoch 1 Progress: 59.2%	Loss: 0.6027
# Train Epoch 1 Progress: 59.73%	Loss: 0.3057
# Train Epoch 1 Progress: 60.27%	Loss: 0.2469
# Train Epoch 1 Progress: 60.8%	Loss: 0.604
# Train Epoch 1 Progress: 61.33%	Loss: 0.2893
# Train Epoch 1 Progress: 61.87%	Loss: 0.3075
# Train Epoch 1 Progress: 62.4%	Loss: 0.2328
# Train Epoch 1 Progress: 62.93%	Loss: 0.3608
# Train Epoch 1 Progress: 63.47%	Loss: 0.3781
# Train Epoch 1 Progress: 64.0%	Loss: 0.3118
# Train Epoch 1 Progress: 64.53%	Loss: 0.2167
# Train Epoch 1 Progress: 65.07%	Loss: 0.3649
# Train Epoch 1 Progress: 65.6%	Loss: 0.1116
# Train Epoch 1 Progress: 66.13%	Loss: 0.4536
# Train Epoch 1 Progress: 66.67%	Loss: 0.1203
# Train Epoch 1 Progress: 67.2%	Loss: 0.439
# Train Epoch 1 Progress: 67.73%	Loss: 0.8567
# Train Epoch 1 Progress: 68.27%	Loss: 0.3091
# Train Epoch 1 Progress: 68.8%	Loss: 0.5068
# Train Epoch 1 Progress: 69.33%	Loss: 0.2823
# Train Epoch 1 Progress: 69.87%	Loss: 0.3143
# Train Epoch 1 Progress: 70.4%	Loss: 0.555
# Train Epoch 1 Progress: 70.93%	Loss: 0.3562
# Train Epoch 1 Progress: 71.47%	Loss: 0.2463
# Train Epoch 1 Progress: 72.0%	Loss: 0.2641
# Train Epoch 1 Progress: 72.53%	Loss: 0.3184
# Train Epoch 1 Progress: 73.07%	Loss: 0.3474
# Train Epoch 1 Progress: 73.6%	Loss: 0.2073
# Train Epoch 1 Progress: 74.13%	Loss: 0.1875
# Train Epoch 1 Progress: 74.67%	Loss: 0.2731
# Train Epoch 1 Progress: 75.2%	Loss: 0.109
# Train Epoch 1 Progress: 75.73%	Loss: 0.7963
# Train Epoch 1 Progress: 76.27%	Loss: 0.3419
# Train Epoch 1 Progress: 76.8%	Loss: 0.4933
# Train Epoch 1 Progress: 77.33%	Loss: 0.4012
# Train Epoch 1 Progress: 77.87%	Loss: 0.499
# Train Epoch 1 Progress: 78.4%	Loss: 0.3877
# Train Epoch 1 Progress: 78.93%	Loss: 0.3895
# Train Epoch 1 Progress: 79.47%	Loss: 0.5635
# Train Epoch 1 Progress: 80.0%	Loss: 0.1948
# Train Epoch 1 Progress: 80.53%	Loss: 0.2127
# Train Epoch 1 Progress: 81.07%	Loss: 0.2554
# Train Epoch 1 Progress: 81.6%	Loss: 0.3175
# Train Epoch 1 Progress: 82.13%	Loss: 0.4343
# Train Epoch 1 Progress: 82.67%	Loss: 0.3389
# Train Epoch 1 Progress: 83.2%	Loss: 0.3571
# Train Epoch 1 Progress: 83.73%	Loss: 0.5047
# Train Epoch 1 Progress: 84.27%	Loss: 0.2632
# Train Epoch 1 Progress: 84.8%	Loss: 0.5012
# Train Epoch 1 Progress: 85.33%	Loss: 0.2509
# Train Epoch 1 Progress: 85.87%	Loss: 0.1306
# Train Epoch 1 Progress: 86.4%	Loss: 0.2969
# Train Epoch 1 Progress: 86.93%	Loss: 0.4242
# Train Epoch 1 Progress: 87.47%	Loss: 0.2797
# Train Epoch 1 Progress: 88.0%	Loss: 0.443
# Train Epoch 1 Progress: 88.53%	Loss: 0.4261
# Train Epoch 1 Progress: 89.07%	Loss: 0.6178
# Train Epoch 1 Progress: 89.6%	Loss: 0.3106
# Train Epoch 1 Progress: 90.13%	Loss: 0.1071
# Train Epoch 1 Progress: 90.67%	Loss: 0.153
# Train Epoch 1 Progress: 91.2%	Loss: 0.3885
# Train Epoch 1 Progress: 91.73%	Loss: 0.2098
# Train Epoch 1 Progress: 92.27%	Loss: 0.1331
# Train Epoch 1 Progress: 92.8%	Loss: 0.2574
# Train Epoch 1 Progress: 93.33%	Loss: 0.5485
# Train Epoch 1 Progress: 93.87%	Loss: 0.3295
# Train Epoch 1 Progress: 94.4%	Loss: 0.468
# Train Epoch 1 Progress: 94.93%	Loss: 0.3572
# Train Epoch 1 Progress: 95.47%	Loss: 0.2793
# Train Epoch 1 Progress: 96.0%	Loss: 0.3938
# Train Epoch 1 Progress: 96.53%	Loss: 0.2363
# Train Epoch 1 Progress: 97.07%	Loss: 0.2685
# Train Epoch 1 Progress: 97.6%	Loss: 0.4557
# Train Epoch 1 Progress: 98.13%	Loss: 0.4222
# Train Epoch 1 Progress: 98.67%	Loss: 0.1879
# Train Epoch 1 Progress: 99.2%	Loss: 0.3747
# Train Epoch 1 Progress: 99.73%	Loss: 0.3758
#
# Test set: Avg loss 0.12, Accuracy 96.48%
#
# Training with lr=0.001, momentum=0.9, batch_size=64
#
# Test set: Avg loss 2.3065, Accuracy 9.5%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3287
# Train Epoch 0 Progress: 1.07%	Loss: 2.2744
# Train Epoch 0 Progress: 2.13%	Loss: 2.3208
# Train Epoch 0 Progress: 3.2%	Loss: 2.2882
# Train Epoch 0 Progress: 4.27%	Loss: 2.303
# Train Epoch 0 Progress: 5.33%	Loss: 2.288
# Train Epoch 0 Progress: 6.4%	Loss: 2.2866
# Train Epoch 0 Progress: 7.47%	Loss: 2.2651
# Train Epoch 0 Progress: 8.53%	Loss: 2.2371
# Train Epoch 0 Progress: 9.6%	Loss: 2.2439
# Train Epoch 0 Progress: 10.67%	Loss: 2.1751
# Train Epoch 0 Progress: 11.73%	Loss: 2.1882
# Train Epoch 0 Progress: 12.8%	Loss: 2.1526
# Train Epoch 0 Progress: 13.87%	Loss: 2.076
# Train Epoch 0 Progress: 14.93%	Loss: 2.186
# Train Epoch 0 Progress: 16.0%	Loss: 2.0752
# Train Epoch 0 Progress: 17.07%	Loss: 2.0375
# Train Epoch 0 Progress: 18.13%	Loss: 1.8515
# Train Epoch 0 Progress: 19.2%	Loss: 1.9143
# Train Epoch 0 Progress: 20.27%	Loss: 1.8458
# Train Epoch 0 Progress: 21.33%	Loss: 1.8483
# Train Epoch 0 Progress: 22.4%	Loss: 1.7419
# Train Epoch 0 Progress: 23.47%	Loss: 1.5289
# Train Epoch 0 Progress: 24.53%	Loss: 1.6794
# Train Epoch 0 Progress: 25.6%	Loss: 1.5054
# Train Epoch 0 Progress: 26.67%	Loss: 1.3214
# Train Epoch 0 Progress: 27.73%	Loss: 1.373
# Train Epoch 0 Progress: 28.8%	Loss: 1.5264
# Train Epoch 0 Progress: 29.87%	Loss: 1.2775
# Train Epoch 0 Progress: 30.93%	Loss: 1.1791
# Train Epoch 0 Progress: 32.0%	Loss: 1.1716
# Train Epoch 0 Progress: 33.07%	Loss: 1.2113
# Train Epoch 0 Progress: 34.13%	Loss: 1.2243
# Train Epoch 0 Progress: 35.2%	Loss: 1.0797
# Train Epoch 0 Progress: 36.27%	Loss: 1.1867
# Train Epoch 0 Progress: 37.33%	Loss: 1.126
# Train Epoch 0 Progress: 38.4%	Loss: 0.9429
# Train Epoch 0 Progress: 39.47%	Loss: 1.1239
# Train Epoch 0 Progress: 40.53%	Loss: 1.0582
# Train Epoch 0 Progress: 41.6%	Loss: 0.8743
# Train Epoch 0 Progress: 42.67%	Loss: 1.1951
# Train Epoch 0 Progress: 43.73%	Loss: 1.0078
# Train Epoch 0 Progress: 44.8%	Loss: 0.9868
# Train Epoch 0 Progress: 45.87%	Loss: 0.9321
# Train Epoch 0 Progress: 46.93%	Loss: 0.8968
# Train Epoch 0 Progress: 48.0%	Loss: 0.7772
# Train Epoch 0 Progress: 49.07%	Loss: 1.0896
# Train Epoch 0 Progress: 50.13%	Loss: 0.7737
# Train Epoch 0 Progress: 51.2%	Loss: 0.9484
# Train Epoch 0 Progress: 52.27%	Loss: 0.8834
# Train Epoch 0 Progress: 53.33%	Loss: 0.7497
# ...
# Train Epoch 1 Progress: 59.73%	Loss: 2.3148
# Train Epoch 1 Progress: 60.27%	Loss: 2.2826
# Train Epoch 1 Progress: 60.8%	Loss: 2.3078
# Train Epoch 1 Progress: 61.33%	Loss: 2.325
# Train Epoch 1 Progress: 61.87%	Loss: 2.3232
# Train Epoch 1 Progress: 62.4%	Loss: 2.2912
# Train Epoch 1 Progress: 62.93%	Loss: 2.3012
# Train Epoch 1 Progress: 63.47%	Loss: 2.3148
# Train Epoch 1 Progress: 64.0%	Loss: 2.3476
# Train Epoch 1 Progress: 64.53%	Loss: 2.2597
# Train Epoch 1 Progress: 65.07%	Loss: 2.2985
# Train Epoch 1 Progress: 65.6%	Loss: 2.4281
# Train Epoch 1 Progress: 66.13%	Loss: 2.3309
# Train Epoch 1 Progress: 66.67%	Loss: 2.2766
# Train Epoch 1 Progress: 67.2%	Loss: 2.3114
# Train Epoch 1 Progress: 67.73%	Loss: 2.2761
# Train Epoch 1 Progress: 68.27%	Loss: 2.3226
# Train Epoch 1 Progress: 68.8%	Loss: 2.2796
# Train Epoch 1 Progress: 69.33%	Loss: 2.3112
# Train Epoch 1 Progress: 69.87%	Loss: 2.2838
# Train Epoch 1 Progress: 70.4%	Loss: 2.3048
# Train Epoch 1 Progress: 70.93%	Loss: 2.3249
# Train Epoch 1 Progress: 71.47%	Loss: 2.3157
# Train Epoch 1 Progress: 72.0%	Loss: 2.3179
# Train Epoch 1 Progress: 72.53%	Loss: 2.3226
# Train Epoch 1 Progress: 73.07%	Loss: 2.286
# Train Epoch 1 Progress: 73.6%	Loss: 2.3051
# Train Epoch 1 Progress: 74.13%	Loss: 2.3461
# Train Epoch 1 Progress: 74.67%	Loss: 2.3509
# Train Epoch 1 Progress: 75.2%	Loss: 2.3004
# Train Epoch 1 Progress: 75.73%	Loss: 2.3032
# Train Epoch 1 Progress: 76.27%	Loss: 2.2896
# Train Epoch 1 Progress: 76.8%	Loss: 2.3145
# Train Epoch 1 Progress: 77.33%	Loss: 2.2908
# Train Epoch 1 Progress: 77.87%	Loss: 2.3185
# Train Epoch 1 Progress: 78.4%	Loss: 2.3336
# Train Epoch 1 Progress: 78.93%	Loss: 2.292
# Train Epoch 1 Progress: 79.47%	Loss: 2.3205
# Train Epoch 1 Progress: 80.0%	Loss: 2.2908
# Train Epoch 1 Progress: 80.53%	Loss: 2.3021
# Train Epoch 1 Progress: 81.07%	Loss: 2.3265
# Train Epoch 1 Progress: 81.6%	Loss: 2.2988
# Train Epoch 1 Progress: 82.13%	Loss: 2.3112
# Train Epoch 1 Progress: 82.67%	Loss: 2.31
# Train Epoch 1 Progress: 83.2%	Loss: 2.284
# Train Epoch 1 Progress: 83.73%	Loss: 2.3407
# Train Epoch 1 Progress: 84.27%	Loss: 2.3121
# Train Epoch 1 Progress: 84.8%	Loss: 2.3022
# Train Epoch 1 Progress: 85.33%	Loss: 2.2909
# Train Epoch 1 Progress: 85.87%	Loss: 2.2972
# Train Epoch 1 Progress: 86.4%	Loss: 2.3248
# Train Epoch 1 Progress: 86.93%	Loss: 2.3287
# Train Epoch 1 Progress: 87.47%	Loss: 2.3162
# Train Epoch 1 Progress: 88.0%	Loss: 2.3187
# Train Epoch 1 Progress: 88.53%	Loss: 2.3094
# Train Epoch 1 Progress: 89.07%	Loss: 2.3044
# Train Epoch 1 Progress: 89.6%	Loss: 2.352
# Train Epoch 1 Progress: 90.13%	Loss: 2.3264
# Train Epoch 1 Progress: 90.67%	Loss: 2.3145
# Train Epoch 1 Progress: 91.2%	Loss: 2.3196
# Train Epoch 1 Progress: 91.73%	Loss: 2.2843
# Train Epoch 1 Progress: 92.27%	Loss: 2.3178
# Train Epoch 1 Progress: 92.8%	Loss: 2.2801
# Train Epoch 1 Progress: 93.33%	Loss: 2.3341
# Train Epoch 1 Progress: 93.87%	Loss: 2.336
# Train Epoch 1 Progress: 94.4%	Loss: 2.3312
# Train Epoch 1 Progress: 94.93%	Loss: 2.2863
# Train Epoch 1 Progress: 95.47%	Loss: 2.2724
# Train Epoch 1 Progress: 96.0%	Loss: 2.2952
# Train Epoch 1 Progress: 96.53%	Loss: 2.3244
# Train Epoch 1 Progress: 97.07%	Loss: 2.2743
# Train Epoch 1 Progress: 97.6%	Loss: 2.362
# Train Epoch 1 Progress: 98.13%	Loss: 2.3075
# Train Epoch 1 Progress: 98.67%	Loss: 2.3092
# Train Epoch 1 Progress: 99.2%	Loss: 2.3009
# Train Epoch 1 Progress: 99.73%	Loss: 2.3005
#
# Test set: Avg loss 2.3111, Accuracy 10.28%
#
# Training with lr=0.1, momentum=0.9, batch_size=64
#
# Test set: Avg loss 2.3195, Accuracy 12.01%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3197
# Train Epoch 0 Progress: 1.07%	Loss: 2.0772
# Train Epoch 0 Progress: 2.13%	Loss: 1.6818
# Train Epoch 0 Progress: 3.2%	Loss: 1.6487
# Train Epoch 0 Progress: 4.27%	Loss: 2.0355
# Train Epoch 0 Progress: 5.33%	Loss: 1.6563
# Train Epoch 0 Progress: 6.4%	Loss: 1.7369
# Train Epoch 0 Progress: 7.47%	Loss: 1.8334
# Train Epoch 0 Progress: 8.53%	Loss: 2.5363
# Train Epoch 0 Progress: 9.6%	Loss: 1.9322
# Train Epoch 0 Progress: 10.67%	Loss: 2.1874
# Train Epoch 0 Progress: 11.73%	Loss: 1.945
# Train Epoch 0 Progress: 12.8%	Loss: 2.3299
# Train Epoch 0 Progress: 13.87%	Loss: 2.3687
# Train Epoch 0 Progress: 14.93%	Loss: 2.2933
# Train Epoch 0 Progress: 16.0%	Loss: 2.2678
# Train Epoch 0 Progress: 17.07%	Loss: 2.2658
# Train Epoch 0 Progress: 18.13%	Loss: 2.2587
# Train Epoch 0 Progress: 19.2%	Loss: 2.2456
# Train Epoch 0 Progress: 20.27%	Loss: 2.2929
# Train Epoch 0 Progress: 21.33%	Loss: 2.3014
# Train Epoch 0 Progress: 22.4%	Loss: 2.2953
# Train Epoch 0 Progress: 23.47%	Loss: 2.291
# Train Epoch 0 Progress: 24.53%	Loss: 2.2969
# Train Epoch 0 Progress: 25.6%	Loss: 2.3234
# Train Epoch 0 Progress: 26.67%	Loss: 2.3221
# Train Epoch 0 Progress: 27.73%	Loss: 2.2961
# Train Epoch 0 Progress: 28.8%	Loss: 2.3035
# Train Epoch 0 Progress: 29.87%	Loss: 2.3024
# Train Epoch 0 Progress: 30.93%	Loss: 2.3141
# Train Epoch 0 Progress: 32.0%	Loss: 2.2999
# Train Epoch 0 Progress: 33.07%	Loss: 2.2786
# Train Epoch 0 Progress: 34.13%	Loss: 2.3029
# Train Epoch 0 Progress: 35.2%	Loss: 2.2899
# Train Epoch 0 Progress: 36.27%	Loss: 2.3112
# Train Epoch 0 Progress: 37.33%	Loss: 2.318
# Train Epoch 0 Progress: 38.4%	Loss: 2.2957
# Train Epoch 0 Progress: 39.47%	Loss: 2.3074
# Train Epoch 0 Progress: 40.53%	Loss: 2.3074
# Train Epoch 0 Progress: 41.6%	Loss: 2.3096
# Train Epoch 0 Progress: 42.67%	Loss: 2.3029
# Train Epoch 0 Progress: 43.73%	Loss: 2.3057
# Train Epoch 0 Progress: 44.8%	Loss: 2.3145
# Train Epoch 0 Progress: 45.87%	Loss: 2.2822
# Train Epoch 0 Progress: 46.93%	Loss: 2.3037
# Train Epoch 0 Progress: 48.0%	Loss: 2.2887
# Train Epoch 0 Progress: 49.07%	Loss: 2.3016
# Train Epoch 0 Progress: 50.13%	Loss: 2.3002
# Train Epoch 0 Progress: 51.2%	Loss: 2.3043
# Train Epoch 0 Progress: 52.27%	Loss: 2.2974
# Train Epoch 0 Progress: 53.33%	Loss: 2.302
# Train Epoch 0 Progress: 54.4%	Loss: 2.3127
# Train Epoch 0 Progress: 55.47%	Loss: 2.3106
# Train Epoch 0 Progress: 56.53%	Loss: 2.2962
# Train Epoch 0 Progress: 57.6%	Loss: 2.3308
# Train Epoch 0 Progress: 58.67%	Loss: 2.3019
# Train Epoch 0 Progress: 59.73%	Loss: 2.2942
# Train Epoch 0 Progress: 60.8%	Loss: 2.3178
# Train Epoch 0 Progress: 61.87%	Loss: 2.3129
# Train Epoch 0 Progress: 62.93%	Loss: 2.2602
# Train Epoch 0 Progress: 64.0%	Loss: 2.289
# Train Epoch 0 Progress: 65.07%	Loss: 2.3065
# Train Epoch 0 Progress: 66.13%	Loss: 2.2966
# Train Epoch 0 Progress: 67.2%	Loss: 2.3079
# Train Epoch 0 Progress: 68.27%	Loss: 2.3249
# Train Epoch 0 Progress: 69.33%	Loss: 2.3003
# Train Epoch 0 Progress: 70.4%	Loss: 2.3188
# Train Epoch 0 Progress: 71.47%	Loss: 2.3064
# Train Epoch 0 Progress: 72.53%	Loss: 2.3116
# Train Epoch 0 Progress: 73.6%	Loss: 2.3205
# Train Epoch 0 Progress: 74.67%	Loss: 2.2968
# Train Epoch 0 Progress: 75.73%	Loss: 2.3141
# Train Epoch 0 Progress: 76.8%	Loss: 2.317
# Train Epoch 0 Progress: 77.87%	Loss: 2.3137
# Train Epoch 0 Progress: 78.93%	Loss: 2.3115
# Train Epoch 0 Progress: 80.0%	Loss: 2.3069
# Train Epoch 0 Progress: 81.07%	Loss: 2.2964
# Train Epoch 0 Progress: 82.13%	Loss: 2.3067
# Train Epoch 0 Progress: 83.2%	Loss: 2.2977
# Train Epoch 0 Progress: 84.27%	Loss: 2.301
# Train Epoch 0 Progress: 85.33%	Loss: 2.3105
# Train Epoch 0 Progress: 86.4%	Loss: 2.2862
# Train Epoch 0 Progress: 87.47%	Loss: 2.3186
# Train Epoch 0 Progress: 88.53%	Loss: 2.2933
# Train Epoch 0 Progress: 89.6%	Loss: 2.306
# Train Epoch 0 Progress: 90.67%	Loss: 2.2815
# Train Epoch 0 Progress: 91.73%	Loss: 2.3091
# Train Epoch 0 Progress: 92.8%	Loss: 2.3113
# Train Epoch 0 Progress: 93.87%	Loss: 2.3043
# Train Epoch 0 Progress: 94.93%	Loss: 2.3411
# Train Epoch 0 Progress: 96.0%	Loss: 2.3391
# Train Epoch 0 Progress: 97.07%	Loss: 2.2636
# Train Epoch 0 Progress: 98.13%	Loss: 2.3004
# Train Epoch 0 Progress: 99.2%	Loss: 2.2976
#
# Test set: Avg loss 2.3054, Accuracy 9.74%
#
# Train Epoch 1 Progress: 0.0%	Loss: 2.3011
# Train Epoch 1 Progress: 1.07%	Loss: 2.2888
# Train Epoch 1 Progress: 2.13%	Loss: 2.3017
# Train Epoch 1 Progress: 3.2%	Loss: 2.3284
# Train Epoch 1 Progress: 4.27%	Loss: 2.3058
# Train Epoch 1 Progress: 5.33%	Loss: 2.2872
# Train Epoch 1 Progress: 6.4%	Loss: 2.3142
# Train Epoch 1 Progress: 7.47%	Loss: 2.285
# Train Epoch 1 Progress: 8.53%	Loss: 2.3205
# Train Epoch 1 Progress: 9.6%	Loss: 2.3024
# Train Epoch 1 Progress: 10.67%	Loss: 2.2995
# Train Epoch 1 Progress: 11.73%	Loss: 2.3018
# Train Epoch 1 Progress: 12.8%	Loss: 2.3084
# Train Epoch 1 Progress: 13.87%	Loss: 2.2905
# Train Epoch 1 Progress: 14.93%	Loss: 2.3244
# Train Epoch 1 Progress: 16.0%	Loss: 2.3076
# Train Epoch 1 Progress: 17.07%	Loss: 2.3148
# Train Epoch 1 Progress: 18.13%	Loss: 2.3164
# Train Epoch 1 Progress: 19.2%	Loss: 2.3033
# Train Epoch 1 Progress: 20.27%	Loss: 2.2877
# Train Epoch 1 Progress: 21.33%	Loss: 2.3184
# Train Epoch 1 Progress: 22.4%	Loss: 2.3019
# Train Epoch 1 Progress: 23.47%	Loss: 2.3089
# Train Epoch 1 Progress: 24.53%	Loss: 2.3026
# Train Epoch 1 Progress: 25.6%	Loss: 2.3076
# Train Epoch 1 Progress: 26.67%	Loss: 2.3022
# Train Epoch 1 Progress: 27.73%	Loss: 2.3326
# Train Epoch 1 Progress: 28.8%	Loss: 2.2924
# Train Epoch 1 Progress: 29.87%	Loss: 2.3145
# Train Epoch 1 Progress: 30.93%	Loss: 2.3037
# Train Epoch 1 Progress: 32.0%	Loss: 2.2963
# Train Epoch 1 Progress: 33.07%	Loss: 2.3025
# Train Epoch 1 Progress: 34.13%	Loss: 2.3084
# Train Epoch 1 Progress: 35.2%	Loss: 2.3078
# Train Epoch 1 Progress: 36.27%	Loss: 2.3024
# Train Epoch 1 Progress: 37.33%	Loss: 2.2919
# Train Epoch 1 Progress: 38.4%	Loss: 2.2839
# Train Epoch 1 Progress: 39.47%	Loss: 2.3169
# Train Epoch 1 Progress: 40.53%	Loss: 2.3086
# Train Epoch 1 Progress: 41.6%	Loss: 2.3074
# Train Epoch 1 Progress: 42.67%	Loss: 2.3288
# Train Epoch 1 Progress: 43.73%	Loss: 2.3041
# Train Epoch 1 Progress: 44.8%	Loss: 2.3094
# Train Epoch 1 Progress: 45.87%	Loss: 2.2909
# Train Epoch 1 Progress: 46.93%	Loss: 2.2944
# Train Epoch 1 Progress: 48.0%	Loss: 2.3257
# Train Epoch 1 Progress: 49.07%	Loss: 2.3052
# Train Epoch 1 Progress: 50.13%	Loss: 2.3111
# Train Epoch 1 Progress: 51.2%	Loss: 2.3016
# Train Epoch 1 Progress: 52.27%	Loss: 2.297
# Train Epoch 1 Progress: 53.33%	Loss: 2.3052
# Train Epoch 1 Progress: 54.4%	Loss: 2.3171
# Train Epoch 1 Progress: 55.47%	Loss: 2.3042
# Train Epoch 1 Progress: 56.53%	Loss: 2.3008
# Train Epoch 1 Progress: 57.6%	Loss: 2.3029
# Train Epoch 1 Progress: 58.67%	Loss: 2.3124
# Train Epoch 1 Progress: 59.73%	Loss: 2.3117
# Train Epoch 1 Progress: 60.8%	Loss: 2.2941
# Train Epoch 1 Progress: 61.87%	Loss: 2.28
# Train Epoch 1 Progress: 62.93%	Loss: 2.3072
# Train Epoch 1 Progress: 64.0%	Loss: 2.3015
# Train Epoch 1 Progress: 65.07%	Loss: 2.2842
# Train Epoch 1 Progress: 66.13%	Loss: 2.3064
# Train Epoch 1 Progress: 67.2%	Loss: 2.3347
# Train Epoch 1 Progress: 68.27%	Loss: 2.3032
# Train Epoch 1 Progress: 69.33%	Loss: 2.3036
# Train Epoch 1 Progress: 70.4%	Loss: 2.2851
# Train Epoch 1 Progress: 71.47%	Loss: 2.3214
# Train Epoch 1 Progress: 72.53%	Loss: 2.301
# Train Epoch 1 Progress: 73.6%	Loss: 2.3129
# Train Epoch 1 Progress: 74.67%	Loss: 2.3187
# Train Epoch 1 Progress: 75.73%	Loss: 2.3048
# Train Epoch 1 Progress: 76.8%	Loss: 2.3087
# Train Epoch 1 Progress: 77.87%	Loss: 2.3091
# Train Epoch 1 Progress: 78.93%	Loss: 2.3077
# Train Epoch 1 Progress: 80.0%	Loss: 2.3098
# Train Epoch 1 Progress: 81.07%	Loss: 2.2885
# Train Epoch 1 Progress: 82.13%	Loss: 2.3146
# Train Epoch 1 Progress: 83.2%	Loss: 2.2967
# Train Epoch 1 Progress: 84.27%	Loss: 2.3086
# Train Epoch 1 Progress: 85.33%	Loss: 2.3024
# Train Epoch 1 Progress: 86.4%	Loss: 2.2943
# Train Epoch 1 Progress: 87.47%	Loss: 2.2973
# Train Epoch 1 Progress: 88.53%	Loss: 2.311
# Train Epoch 1 Progress: 89.6%	Loss: 2.3122
# Train Epoch 1 Progress: 90.67%	Loss: 2.3192
# Train Epoch 1 Progress: 91.73%	Loss: 2.2938
# Train Epoch 1 Progress: 92.8%	Loss: 2.2974
# Train Epoch 1 Progress: 93.87%	Loss: 2.306
# Train Epoch 1 Progress: 94.93%	Loss: 2.3217
# Train Epoch 1 Progress: 96.0%	Loss: 2.3023
# Train Epoch 1 Progress: 97.07%	Loss: 2.3052
# Train Epoch 1 Progress: 98.13%	Loss: 2.2995
# Train Epoch 1 Progress: 99.2%	Loss: 2.3064
#
# Test set: Avg loss 2.3046, Accuracy 9.58%
#
# Training with lr=0.1, momentum=0.9, batch_size=128
#
# Test set: Avg loss 2.3214, Accuracy 10.28%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3515
# Train Epoch 0 Progress: 2.13%	Loss: 2.027
# Train Epoch 0 Progress: 4.27%	Loss: 1.4632
# Train Epoch 0 Progress: 6.4%	Loss: 1.202
# Train Epoch 0 Progress: 8.53%	Loss: 1.0109
# Train Epoch 0 Progress: 10.67%	Loss: 0.9336
# Train Epoch 0 Progress: 12.8%	Loss: 0.7355
# Train Epoch 0 Progress: 14.93%	Loss: 1.0003
# Train Epoch 0 Progress: 17.07%	Loss: 1.1231
# Train Epoch 0 Progress: 19.2%	Loss: 0.9261
# Train Epoch 0 Progress: 21.33%	Loss: 1.0022
# Train Epoch 0 Progress: 23.47%	Loss: 1.3739
# Train Epoch 0 Progress: 25.6%	Loss: 0.8588
# Train Epoch 0 Progress: 27.73%	Loss: 0.925
# Train Epoch 0 Progress: 29.87%	Loss: 1.0411
# Train Epoch 0 Progress: 32.0%	Loss: 0.8735
# Train Epoch 0 Progress: 34.13%	Loss: 1.1039
# Train Epoch 0 Progress: 36.27%	Loss: 0.7322
# Train Epoch 0 Progress: 38.4%	Loss: 0.6535
# Train Epoch 0 Progress: 40.53%	Loss: 0.8685
# Train Epoch 0 Progress: 42.67%	Loss: 0.7175
# Train Epoch 0 Progress: 44.8%	Loss: 0.7167
# Train Epoch 0 Progress: 46.93%	Loss: 0.5208
# Train Epoch 0 Progress: 49.07%	Loss: 1.0281
# Train Epoch 0 Progress: 51.2%	Loss: 0.7145
# Train Epoch 0 Progress: 53.33%	Loss: 0.773
# Train Epoch 0 Progress: 55.47%	Loss: 0.5836
# Train Epoch 0 Progress: 57.6%	Loss: 0.849
# Train Epoch 0 Progress: 59.73%	Loss: 0.8484
# Train Epoch 0 Progress: 61.87%	Loss: 0.8307
# Train Epoch 0 Progress: 64.0%	Loss: 0.9626
# Train Epoch 0 Progress: 66.13%	Loss: 0.8018
# Train Epoch 0 Progress: 68.27%	Loss: 0.6044
# Train Epoch 0 Progress: 70.4%	Loss: 0.8168
# Train Epoch 0 Progress: 72.53%	Loss: 0.8749
# Train Epoch 0 Progress: 74.67%	Loss: 0.7075
# Train Epoch 0 Progress: 76.8%	Loss: 0.8662
# Train Epoch 0 Progress: 78.93%	Loss: 0.6078
# Train Epoch 0 Progress: 81.07%	Loss: 0.689
# Train Epoch 0 Progress: 83.2%	Loss: 0.6822
# Train Epoch 0 Progress: 85.33%	Loss: 0.8501
# Train Epoch 0 Progress: 87.47%	Loss: 0.9868
# Train Epoch 0 Progress: 89.6%	Loss: 0.9025
# Train Epoch 0 Progress: 91.73%	Loss: 0.9204
# Train Epoch 0 Progress: 93.87%	Loss: 0.5666
# Train Epoch 0 Progress: 96.0%	Loss: 0.7065
# Train Epoch 0 Progress: 98.13%	Loss: 0.7654
#
# Test set: Avg loss 0.2241, Accuracy 93.78%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.5026
# Train Epoch 1 Progress: 2.13%	Loss: 0.6253
# Train Epoch 1 Progress: 4.27%	Loss: 0.4059
# Train Epoch 1 Progress: 6.4%	Loss: 0.5875
# Train Epoch 1 Progress: 8.53%	Loss: 0.6609
# Train Epoch 1 Progress: 10.67%	Loss: 0.5448
# Train Epoch 1 Progress: 12.8%	Loss: 0.6768
# Train Epoch 1 Progress: 14.93%	Loss: 0.6975
# Train Epoch 1 Progress: 17.07%	Loss: 0.6222
# Train Epoch 1 Progress: 19.2%	Loss: 0.7624
# Train Epoch 1 Progress: 21.33%	Loss: 0.6387
# Train Epoch 1 Progress: 23.47%	Loss: 0.8624
# Train Epoch 1 Progress: 25.6%	Loss: 0.8
# Train Epoch 1 Progress: 27.73%	Loss: 0.7254
# Train Epoch 1 Progress: 29.87%	Loss: 0.8644
# Train Epoch 1 Progress: 32.0%	Loss: 0.5338
# Train Epoch 1 Progress: 34.13%	Loss: 0.7935
# Train Epoch 1 Progress: 36.27%	Loss: 0.7306
# Train Epoch 1 Progress: 38.4%	Loss: 0.8707
# Train Epoch 1 Progress: 40.53%	Loss: 0.6651
# Train Epoch 1 Progress: 42.67%	Loss: 0.786
# Train Epoch 1 Progress: 44.8%	Loss: 1.0081
# Train Epoch 1 Progress: 46.93%	Loss: 0.6765
# Train Epoch 1 Progress: 49.07%	Loss: 0.661
# Train Epoch 1 Progress: 51.2%	Loss: 0.5224
# Train Epoch 1 Progress: 53.33%	Loss: 0.7511
# Train Epoch 1 Progress: 55.47%	Loss: 0.4802
# Train Epoch 1 Progress: 57.6%	Loss: 0.6919
# Train Epoch 1 Progress: 59.73%	Loss: 0.8581
# Train Epoch 1 Progress: 61.87%	Loss: 0.6048
# Train Epoch 1 Progress: 64.0%	Loss: 0.6023
# Train Epoch 1 Progress: 66.13%	Loss: 0.4537
# Train Epoch 1 Progress: 68.27%	Loss: 0.5282
# Train Epoch 1 Progress: 70.4%	Loss: 0.6765
# Train Epoch 1 Progress: 72.53%	Loss: 0.5842
# Train Epoch 1 Progress: 74.67%	Loss: 0.5033
# Train Epoch 1 Progress: 76.8%	Loss: 0.5756
# Train Epoch 1 Progress: 78.93%	Loss: 0.8407
# Train Epoch 1 Progress: 81.07%	Loss: 0.5773
# Train Epoch 1 Progress: 83.2%	Loss: 0.773
# Train Epoch 1 Progress: 85.33%	Loss: 0.808
# Train Epoch 1 Progress: 87.47%	Loss: 0.5717
# Train Epoch 1 Progress: 89.6%	Loss: 0.5824
# Train Epoch 1 Progress: 91.73%	Loss: 0.4555
# Train Epoch 1 Progress: 93.87%	Loss: 0.6679
# Train Epoch 1 Progress: 96.0%	Loss: 0.6714
# Train Epoch 1 Progress: 98.13%	Loss: 0.6708
#
# Test set: Avg loss 0.2051, Accuracy 94.52%

# %%
# Print the results sorted by accuracy
sorted_results = sorted(results, key=lambda x: x["test_accuracy"], reverse=True)
for result in sorted_results:
    print(result)
# Out:
# {'lr': 0.1, 'momentum': 0.5, 'batch_size': 128, 'test_loss': 0.06866336059570312, 'test_accuracy': 97.82}
# {'lr': 0.01, 'momentum': 0.9, 'batch_size': 64, 'test_loss': 0.07172672824859619, 'test_accuracy': 97.79}
# {'lr': 0.1, 'momentum': 0.5, 'batch_size': 64, 'test_loss': 0.082717112159729, 'test_accuracy': 97.59}
# {'lr': 0.01, 'momentum': 0.9, 'batch_size': 128, 'test_loss': 0.08504637203216553, 'test_accuracy': 97.23}
# {'lr': 0.01, 'momentum': 0.9, 'batch_size': 32, 'test_loss': 0.0955873779296875, 'test_accuracy': 97.09}
# {'lr': 0.01, 'momentum': 0.5, 'batch_size': 32, 'test_loss': 0.09570745124816894, 'test_accuracy': 97.03}
# {'lr': 0.001, 'momentum': 0.9, 'batch_size': 32, 'test_loss': 0.11999910278320312, 'test_accuracy': 96.48}
# {'lr': 0.1, 'momentum': 0.5, 'batch_size': 32, 'test_loss': 0.1269976921081543, 'test_accuracy': 96.29}
# {'lr': 0.01, 'momentum': 0.5, 'batch_size': 64, 'test_loss': 0.12217017097473144, 'test_accuracy': 96.25}
# {'lr': 0.001, 'momentum': 0.9, 'batch_size': 64, 'test_loss': 0.16507171821594238, 'test_accuracy': 94.99}
# {'lr': 0.01, 'momentum': 0.5, 'batch_size': 128, 'test_loss': 0.16755046005249025, 'test_accuracy': 94.93}
# {'lr': 0.1, 'momentum': 0.9, 'batch_size': 128, 'test_loss': 0.2051143051147461, 'test_accuracy': 94.52}
# {'lr': 0.001, 'momentum': 0.5, 'batch_size': 32, 'test_loss': 0.29028219757080076, 'test_accuracy': 91.61}
# {'lr': 0.001, 'momentum': 0.9, 'batch_size': 128, 'test_loss': 0.3025534194946289, 'test_accuracy': 91.48}
# {'lr': 0.001, 'momentum': 0.5, 'batch_size': 64, 'test_loss': 0.694466275024414, 'test_accuracy': 85.09}
# {'lr': 0.001, 'momentum': 0.5, 'batch_size': 128, 'test_loss': 1.8896232421875, 'test_accuracy': 53.84}
# {'lr': 0.1, 'momentum': 0.9, 'batch_size': 32, 'test_loss': 2.311112939453125, 'test_accuracy': 10.28}
# {'lr': 0.1, 'momentum': 0.9, 'batch_size': 64, 'test_loss': 2.3046193115234375, 'test_accuracy': 9.58}

# %% [markdown]
# ## Insight into Saving Models
# A common way to save a model is to serialize the internal state dictionary (containing the model parameters).

# %%
torch.save(conv_network.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %% [markdown]
# ## Insight into Loading Models
#
# The process for loading a model includes re-creating the model structure and loading
# the state dictionary into it.

# %%
model = ConvNet()
model.load_state_dict(torch.load("model.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# This model can now be used to make predictions.

# %%
# Download test data from open datasets.
test_data = datasets.MNIST('sample_data/',
    train=False,
    download=True,
    transform=transforms.ToTensor(),
)

classes = [1, 2, 3, 4, 5, 6, 7, 8, 9]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "9", Actual: "8"
