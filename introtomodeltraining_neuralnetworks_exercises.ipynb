# %% [markdown]
# <a href="https://colab.research.google.com/github/bmontoyag/UTEC_MISTI_2026/blob/main/introtomodeltraining_neuralnetworks_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If you haven't already, please hit :**
#
# `File` -> `Save a Copy in Drive`
#
# **to copy this notebook to your Google drive, and work on a copy. If you don't do this, your changes won't be saved!**

# %% [markdown]
# # Train a Simple Neural Network for Regression with the California Housing Dataset

# %% [markdown]
# ## Download the California Housing Datset

# %%
# Import Packages

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import networkx as nx
from torch.utils.data import DataLoader, TensorDataset
import torch

# %% [markdown]
# ## Train a Neural Network model to Predict Median House Value

# %% [markdown]
# Below, we provide a function which can help you visualize the neural network you are creating with an example output from this function as well.

# %%
def visualize_nn_from_model(model):
    """
    Visualizes a neural network architecture from a PyTorch nn.Module.

    Args:
    - model (nn.Module): The PyTorch model to visualize.

    The function interprets linear layers and activation functions, then
    plots a graph representation of the architecture.
    """
    layers = []
    for layer in model.network:
        if isinstance(layer, nn.Linear):
            layers.append(f"Linear ({layer.in_features} → {layer.out_features})")
        elif isinstance(layer, nn.ReLU):
            layers.append("ReLU")
        elif isinstance(layer, nn.Sigmoid):
            layers.append("Sigmoid")
        elif isinstance(layer, nn.Tanh):
            layers.append("Tanh")
        # Add more cases for other layers as needed

    # Build visualization graph
    G = nx.DiGraph()
    positions = {}
    y_offset = 0

    for idx, layer in enumerate(layers):
        node_name = f"L{idx}: {layer}"
        G.add_node(node_name)
        positions[node_name] = (0, -y_offset)
        y_offset += 1

    # Add edges
    for i in range(len(layers) - 1):
        G.add_edge(f"L{i}: {layers[i]}", f"L{i+1}: {layers[i+1]}")

    # Draw the graph
    plt.figure(figsize=(10, len(layers) * 1.5))
    nx.draw(
        G,
        pos=positions,
        with_labels=True,
        node_size=3000,
        node_color="lightblue",
        edge_color="gray",
        arrows=True
    )
    plt.title("Neural Network Architecture", fontsize=16)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### EXERCISE: Define a Simple Neural Network Model
#
# Your objective is to define and implement a simple feedforward neural network with the following structure:
# - Input layer: Accepts the input features.
# - Hidden layer 1: 128 neurons with ReLU activation.
# - Hidden layer 2: 64 neurons with ReLU activation.
# - Output layer: A single neuron (for regression tasks).
#
#
# Tasks:
# 1. Define the Neural Network Model
#   - Create a class named NeuralNetwork that inherits from nn.Module. Inside the class:
#     - Implement the __init__ method to define the network architecture using nn.Sequential. Include the following:
#       - A linear layer connecting the input to 128 neurons using the method `nn.Linear(~)`.
#       - A ReLU activation function using the method `nn.ReLU(~)`.
#       - A linear layer connecting 128 neurons to 64 neurons using the method `nn.Linear(~)`.
#       - Another ReLU activation function using the method `nn.ReLU(~)`.
#       - A linear layer connecting 64 neurons to 1 output neuron using the method `nn.Linear(~)`.
#     - You could alternately define a neural network using the `nn.Sequential(~)` method. This is easier, but less flexible.
# 2. Verify your implementation by creating a dummy input tensor, and running it through your neural network model. *Remember, you haven't trained it yet.*

# %% [markdown]
# #### TASK 1: Build a Neural Network Class

# %%
# TASK 1 EXERCISE

class NeuralNetwork(nn.Module):

    def __init__(self, input_size):
        """
        Initialize the neural network model.

        Args:
            input_size (int): Number of features in the input data.
        """
        # Call the constructor of the parent class (nn.Module)
        super(NeuralNetwork, self).__init__()
        # Define the network architecture
        self.network = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        return self.network(x)

# %% [markdown]
# #### Task 2: Validate your Neural Network Class

# %%
# TASK 2 EXERCISE

# Create an Instance of your Neural Network Class
input_size = 10  # Example input size
model = NeuralNetwork(input_size)  # Initialize the model

# Visualize your Model
visualize_nn_from_model(model)

# Create a dummy input tensor
dummy_input = torch.randn(1, input_size)  # Batch size of 1
output = model(dummy_input)  # Forward pass
print("Output shape:", output.shape)
print("Output: " + str(output))
# Out:
# Output shape: torch.Size([1, 1])
# Output: tensor([[-0.0924]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ### EXERCISE: Write a function to Train your Neural Network Model
#
# Now, we are going to build a function which then trains the neural network model.
#
# Tasks:
# 1. Define the training function:
#   - For each batch of data:
#     - Reset the gradients using `optimizer.zero_grad()`.
#     - Perform a forward pass through the model.
#     - Calculate the loss using the `criterion(~)` function.
#     - Perform backpropagation using `loss.backward()`.
#     - Update the model weights using `optimizer.step()`.
# 2. Train your model with a synthetic dataset.

# %% [markdown]
# #### TASK 1: Build a function to Train your Neural Network Model

# %%
# TASK 1 EXERCISE

def train_model(model, train_loader, criterion, optimizer, epochs=20):
    """
    Train a neural network model.

    Args:
        model: The neural network model to train.
        train_loader: DataLoader for the training dataset.
        criterion: Loss function to minimize.
        optimizer: Optimization algorithm to update model weights.
        epochs (int): Number of epochs to train for.
    """

    model.train()  # Set model to training mode

    for epoch in range(epochs):

        running_loss = 0.0

        for data, targets in train_loader:
            optimizer.zero_grad()  # Zero the parameter gradients
            outputs = model(data).squeeze()  # Forward pass where .squeeze() removes any unnecessary dimensions
            loss = criterion(outputs, targets)  # Compute loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update weights
            running_loss += loss.item()  # Accumulate loss where .item() turns the tensor into a float

        print(f"Epoch {epoch + 1}/{epochs}, Loss: {running_loss / len(train_loader):.4f}")

    pass

# %% [markdown]
# #### TASK 2: Validate your Training Function

# %%
# TASK 2 EXERCISE

# Create a small dummy dataset
X_train = torch.randn(100, 10)
y_train = torch.randn(100)
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=10)

# Define the model, loss function, and optimizer
input_size = 10
model = NeuralNetwork(input_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
train_model(model, train_loader, criterion, optimizer)
# Out:
# Epoch 1/20, Loss: 0.8822
# Epoch 2/20, Loss: 0.7850
# Epoch 3/20, Loss: 0.7378
# Epoch 4/20, Loss: 0.6928
# Epoch 5/20, Loss: 0.6500
# Epoch 6/20, Loss: 0.6089
# Epoch 7/20, Loss: 0.5673
# Epoch 8/20, Loss: 0.5260
# Epoch 9/20, Loss: 0.4857
# Epoch 10/20, Loss: 0.4450
# Epoch 11/20, Loss: 0.4054
# Epoch 12/20, Loss: 0.3679
# Epoch 13/20, Loss: 0.3309
# Epoch 14/20, Loss: 0.2972
# Epoch 15/20, Loss: 0.2645
# Epoch 16/20, Loss: 0.2350
# Epoch 17/20, Loss: 0.2081
# Epoch 18/20, Loss: 0.1832
# Epoch 19/20, Loss: 0.1596
# Epoch 20/20, Loss: 0.1408

# %% [markdown]
# ### EXERCISE: Make the California Housing Dataset Amenable with PyTorch Dataloaders
#
# Tasks:
# 1. Create a custom dataset class `NewDataset`
#   - Accept data (features) and targets (labels) as input.
#   - Implement the `__len__()` method to return the number of samples.
#   - Implement the `__getitem__()` method to return a sample and its corresponding label as tensors.

# %% [markdown]
# #### TASK 1: Create a Custom Dataset Class

# %%
# TASK 1 EXERCISE

# Custom Dataset
class NewDataset(Dataset):

    def __init__(self, data, targets):
        self.data = torch.tensor(data, dtype=torch.float32)
        self.targets = torch.tensor(targets, dtype=torch.float32)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.targets[idx]

# Load and preprocess the California Housing Dataset
def load_data(test_size=0.2, batch_size=32):

    # Fetch dataset
    housing = fetch_california_housing()
    data, targets = housing.data, housing.target

    # Standardize features
    scaler = StandardScaler()
    data = scaler.fit_transform(data)

    # Split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(data, targets, test_size=test_size, random_state=42)

    # Create PyTorch Datasets
    train_dataset = NewDataset(X_train, y_train)
    test_dataset = NewDataset(X_test, y_test)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# Hyperparameters
batch_size = 32
test_size = 0.2
learning_rate = 0.001
epochs = 20

# Load data
train_loader, test_loader = load_data(test_size, batch_size)

# Iterate through the train_loader and print the shape of data and labels
for batch_idx, (data, labels) in enumerate(train_loader):
    print(f"Batch {batch_idx + 1}:")
    print(f"  Data shape: {data.shape}")
    print(f"  Labels shape: {labels.shape}")
    break  # Stop after the first batch for inspection
# Out:
# Batch 1:
#   Data shape: torch.Size([32, 8])
#   Labels shape: torch.Size([32])

# %% [markdown]
# ### Validate your Model
#
# The following code defines two functions to assess a model's performance: `evaluate_model`, which computes key regression metrics such as Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R² score using predictions from a test dataset, and `plot_predictions`, which visualizes the relationship between predicted and actual values to help evaluate the model's fit.

# %%
# Evaluate the Model
def evaluate_model(model, test_loader, criterion):
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for data, targets in test_loader:
            outputs = model(data).squeeze()
            y_true.extend(targets.numpy())
            y_pred.extend(outputs.numpy())
    # Calculate metrics
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"R² Score: {r2:.4f}")
    return y_true, y_pred

# Plot Predicted vs Actual Values
def plot_predictions(y_true, y_pred):
    plt.figure(figsize=(10, 6))
    plt.scatter(y_true, y_pred, alpha=0.6, label='Predicted vs Actual')
    plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], 'r--', lw=2, label='Ideal Fit')
    plt.title("Predicted vs Actual Values")
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# #### EXERCISE: Train and Validate your Neural Network Model on the California Housing Dataset
#
# Now, let's apply our neural network to a real-world dataset by training it on the California Housing Dataset. We'll need to prepare our data and initialize the model with appropriate parameters.
#
# Tasks:
# 1. Prepare the Data and Initialize the Model
#   - Load the **California Housing dataset** using a data-loading function (e.g., `load_data()`).
#   - **Determine the input size** by extracting the number of features from the training data batch.
#   - **Initialize your neural network model**, specifying the correct input size.
#   - **Set up the loss function** using **`nn.MSELoss()`** and the optimizer using **`optim.Adam()`**.
# 2. Train, Evaluate, and Plot Results
#   - **Train the model** using the `train_model()` function.
#   - **Evaluate the model** using the `evaluate_model()` function to compute predictions on the test set.
#   - **Plot predictions** using the `plot_predictions()` function.

# %% [markdown]
# ##### TASK 1: Prepare the Data and Initialize the Model

# %%
# TASK 1 EXERCISE
# Best Configuration: batch_size=64, learning_rate=0.01, hidden_layers=[24, 12], epochs=15, R²=0.7672
# Hyperparameters
batch_size = 64
test_size = 0.2
learning_rate = 0.01
epochs = 15

# Load data
train_loader, test_loader = load_data(test_size, batch_size)

# Initialize model, loss function, and optimizer
input_size = next(iter(train_loader))[0].shape[1]  # Get number of features
model = NeuralNetwork(input_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ##### TASK 2: Train, Evaluate, and Plot Results

# %%
# TASK 2 SOLUION

# Train and evaluate
print("Training the model...")
train_model(model, train_loader, criterion, optimizer, epochs)

# Evaluate the model
print("\nEvaluating the model...")
y_true, y_pred = evaluate_model(model, test_loader, criterion)

# Plot predictions
plot_predictions(y_true, y_pred)
# Out:
# Training the model...
# Epoch 1/15, Loss: 0.5155
# Epoch 2/15, Loss: 0.3681
# Epoch 3/15, Loss: 0.3631
# Epoch 4/15, Loss: 0.3465
# Epoch 5/15, Loss: 0.3288
# Epoch 6/15, Loss: 0.3539
# Epoch 7/15, Loss: 0.3181
# Epoch 8/15, Loss: 0.3068
# Epoch 9/15, Loss: 0.3033
# Epoch 10/15, Loss: 0.3015
# Epoch 11/15, Loss: 0.3002
# Epoch 12/15, Loss: 0.2962
# Epoch 13/15, Loss: 0.2943
# Epoch 14/15, Loss: 0.2934
# Epoch 15/15, Loss: 0.2891
#
# Evaluating the model...
# Mean Squared Error (MSE): 0.2950
# Root Mean Squared Error (RMSE): 0.5431
# R² Score: 0.7749

# %% [markdown]
# ## (Optional) Hyperparameters

# %% [markdown]
# ### ANALYZE: Build a Function to Test Different Sets of Hyperparameters

# %%
# Function to tune and evaluate
def tune_hyperparameters(batch_size, learning_rate, hidden_layer_sizes, epochs):

    print(f"Tuning: batch_size={batch_size}, learning_rate={learning_rate}, hidden_layers={hidden_layer_sizes}, epochs={epochs}")

    # Load data
    train_loader, test_loader = load_data(test_size=0.2, batch_size=batch_size)

    # Define the model
    class TunableNeuralNetwork(nn.Module):
        def __init__(self, input_size, hidden_layer_sizes):
            super(TunableNeuralNetwork, self).__init__()
            layers = []
            in_features = input_size
            for out_features in hidden_layer_sizes:
                layers.append(nn.Linear(in_features, out_features))
                layers.append(nn.ReLU())
                in_features = out_features
            layers.append(nn.Linear(in_features, 1))
            self.network = nn.Sequential(*layers)

        def forward(self, x):
            return self.network(x)

    input_size = next(iter(train_loader))[0].shape[1]
    model = TunableNeuralNetwork(input_size, hidden_layer_sizes)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Train the model
    train_model(model, train_loader, criterion, optimizer, epochs)

    # Evaluate the model
    y_true, y_pred = evaluate_model(model, test_loader, criterion)

    # Metrics
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    print(f"Metrics: MSE={mse:.4f}, RMSE={rmse:.4f}, R²={r2:.4f}")
    return mse, rmse, r2

# Example: Grid search over parameters
batch_sizes = [32, 64,128]
learning_rates = [0.001, 0.01, 0.05]
hidden_layer_configs = [[24, 12], [6, 3]]
epoch_counts = [5, 10, 15]

best_config = None
best_r2 = -np.inf
for batch_size in batch_sizes:
    for learning_rate in learning_rates:
        for hidden_layers in hidden_layer_configs:
            for epochs in epoch_counts:
                mse, rmse, r2 = tune_hyperparameters(batch_size, learning_rate, hidden_layers, epochs)
                if r2 > best_r2:
                    best_r2 = r2
                    best_config = (batch_size, learning_rate, hidden_layers, epochs, r2)

print(f"Best Configuration: batch_size={best_config[0]}, learning_rate={best_config[1]}, hidden_layers={best_config[2]}, epochs={best_config[3]}, R²={best_config[4]:.4f}")
# Out:
# Tuning: batch_size=32, learning_rate=0.001, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 1.2951
# Epoch 2/5, Loss: 0.4851
# Epoch 3/5, Loss: 0.4084
# Epoch 4/5, Loss: 0.3851
# Epoch 5/5, Loss: 0.3743
# Mean Squared Error (MSE): 0.3828
# Root Mean Squared Error (RMSE): 0.6187
# R² Score: 0.7079
# Metrics: MSE=0.3828, RMSE=0.6187, R²=0.7079
# Tuning: batch_size=32, learning_rate=0.001, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 1.6900
# Epoch 2/10, Loss: 0.5370
# Epoch 3/10, Loss: 0.4383
# Epoch 4/10, Loss: 0.4073
# Epoch 5/10, Loss: 0.3878
# Epoch 6/10, Loss: 0.3791
# Epoch 7/10, Loss: 0.3666
# Epoch 8/10, Loss: 0.3572
# Epoch 9/10, Loss: 0.3566
# Epoch 10/10, Loss: 0.3471
# Mean Squared Error (MSE): 0.3565
# Root Mean Squared Error (RMSE): 0.5970
# R² Score: 0.7280
# Metrics: MSE=0.3565, RMSE=0.5970, R²=0.7280
# Tuning: batch_size=32, learning_rate=0.001, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 1.0777
# Epoch 2/15, Loss: 0.4686
# Epoch 3/15, Loss: 0.4126
# Epoch 4/15, Loss: 0.3893
# Epoch 5/15, Loss: 0.3740
# Epoch 6/15, Loss: 0.3617
# Epoch 7/15, Loss: 0.3522
# Epoch 8/15, Loss: 0.3448
# Epoch 9/15, Loss: 0.3382
# Epoch 10/15, Loss: 0.3317
# Epoch 11/15, Loss: 0.3286
# Epoch 12/15, Loss: 0.3233
# Epoch 13/15, Loss: 0.3195
# Epoch 14/15, Loss: 0.3169
# Epoch 15/15, Loss: 0.3125
# Mean Squared Error (MSE): 0.3219
# Root Mean Squared Error (RMSE): 0.5673
# R² Score: 0.7544
# Metrics: MSE=0.3219, RMSE=0.5673, R²=0.7544
# Tuning: batch_size=32, learning_rate=0.001, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 1.7643
# Epoch 2/5, Loss: 0.5081
# Epoch 3/5, Loss: 0.4407
# Epoch 4/5, Loss: 0.4234
# Epoch 5/5, Loss: 0.4162
# Mean Squared Error (MSE): 0.4260
# Root Mean Squared Error (RMSE): 0.6527
# R² Score: 0.6749
# Metrics: MSE=0.4260, RMSE=0.6527, R²=0.6749
# Tuning: batch_size=32, learning_rate=0.001, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 2.3635
# Epoch 2/10, Loss: 0.5221
# Epoch 3/10, Loss: 0.4367
# Epoch 4/10, Loss: 0.4119
# Epoch 5/10, Loss: 0.4012
# Epoch 6/10, Loss: 0.3931
# Epoch 7/10, Loss: 0.3860
# Epoch 8/10, Loss: 0.3813
# Epoch 9/10, Loss: 0.3770
# Epoch 10/10, Loss: 0.3743
# Mean Squared Error (MSE): 0.3874
# Root Mean Squared Error (RMSE): 0.6224
# R² Score: 0.7043
# Metrics: MSE=0.3874, RMSE=0.6224, R²=0.7043
# Tuning: batch_size=32, learning_rate=0.001, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 2.6545
# Epoch 2/15, Loss: 0.7159
# Epoch 3/15, Loss: 0.5740
# Epoch 4/15, Loss: 0.4904
# Epoch 5/15, Loss: 0.4474
# Epoch 6/15, Loss: 0.4286
# Epoch 7/15, Loss: 0.4191
# Epoch 8/15, Loss: 0.4133
# Epoch 9/15, Loss: 0.4089
# Epoch 10/15, Loss: 0.4055
# Epoch 11/15, Loss: 0.4026
# Epoch 12/15, Loss: 0.4003
# Epoch 13/15, Loss: 0.3978
# Epoch 14/15, Loss: 0.3957
# Epoch 15/15, Loss: 0.3951
# Mean Squared Error (MSE): 0.4026
# Root Mean Squared Error (RMSE): 0.6345
# R² Score: 0.6928
# Metrics: MSE=0.4026, RMSE=0.6345, R²=0.6928
# Tuning: batch_size=32, learning_rate=0.01, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 0.6337
# Epoch 2/5, Loss: 0.3862
# Epoch 3/5, Loss: 0.3537
# Epoch 4/5, Loss: 0.3523
# Epoch 5/5, Loss: 0.3355
# Mean Squared Error (MSE): 0.3592
# Root Mean Squared Error (RMSE): 0.5993
# R² Score: 0.7259
# Metrics: MSE=0.3592, RMSE=0.5993, R²=0.7259
# Tuning: batch_size=32, learning_rate=0.01, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 0.6113
# Epoch 2/10, Loss: 0.3980
# Epoch 3/10, Loss: 0.3659
# Epoch 4/10, Loss: 0.3541
# Epoch 5/10, Loss: 0.3461
# Epoch 6/10, Loss: 0.3486
# Epoch 7/10, Loss: 0.3374
# Epoch 8/10, Loss: 0.3261
# Epoch 9/10, Loss: 0.3236
# Epoch 10/10, Loss: 0.3167
# Mean Squared Error (MSE): 0.3198
# Root Mean Squared Error (RMSE): 0.5655
# R² Score: 0.7559
# Metrics: MSE=0.3198, RMSE=0.5655, R²=0.7559
# Tuning: batch_size=32, learning_rate=0.01, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 0.5712
# Epoch 2/15, Loss: 0.3785
# Epoch 3/15, Loss: 0.3568
# Epoch 4/15, Loss: 0.3492
# Epoch 5/15, Loss: 0.3436
# Epoch 6/15, Loss: 0.3418
# Epoch 7/15, Loss: 0.3331
# Epoch 8/15, Loss: 0.3303
# Epoch 9/15, Loss: 0.3282
# Epoch 10/15, Loss: 0.3268
# Epoch 11/15, Loss: 0.4007
# Epoch 12/15, Loss: 0.3239
# Epoch 13/15, Loss: 0.3137
# Epoch 14/15, Loss: 0.3142
# Epoch 15/15, Loss: 0.3174
# Mean Squared Error (MSE): 0.3137
# Root Mean Squared Error (RMSE): 0.5601
# R² Score: 0.7606
# Metrics: MSE=0.3137, RMSE=0.5601, R²=0.7606
# Tuning: batch_size=32, learning_rate=0.01, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 0.6929
# Epoch 2/5, Loss: 0.4179
# Epoch 3/5, Loss: 0.4078
# Epoch 4/5, Loss: 0.4044
# Epoch 5/5, Loss: 0.3978
# Mean Squared Error (MSE): 0.4010
# Root Mean Squared Error (RMSE): 0.6332
# R² Score: 0.6940
# Metrics: MSE=0.4010, RMSE=0.6332, R²=0.6940
# Tuning: batch_size=32, learning_rate=0.01, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 0.6145
# Epoch 2/10, Loss: 0.4006
# Epoch 3/10, Loss: 0.3848
# Epoch 4/10, Loss: 0.3738
# Epoch 5/10, Loss: 0.3729
# Epoch 6/10, Loss: 0.3682
# Epoch 7/10, Loss: 0.3685
# Epoch 8/10, Loss: 0.3738
# Epoch 9/10, Loss: 0.3628
# Epoch 10/10, Loss: 0.3583
# Mean Squared Error (MSE): 0.3634
# Root Mean Squared Error (RMSE): 0.6028
# R² Score: 0.7227
# Metrics: MSE=0.3634, RMSE=0.6028, R²=0.7227
# Tuning: batch_size=32, learning_rate=0.01, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 0.7573
# Epoch 2/15, Loss: 0.4074
# Epoch 3/15, Loss: 0.3913
# Epoch 4/15, Loss: 0.3828
# Epoch 5/15, Loss: 0.3715
# Epoch 6/15, Loss: 0.3777
# Epoch 7/15, Loss: 0.3584
# Epoch 8/15, Loss: 0.3649
# Epoch 9/15, Loss: 0.3520
# Epoch 10/15, Loss: 0.3542
# Epoch 11/15, Loss: 0.3573
# Epoch 12/15, Loss: 0.3509
# Epoch 13/15, Loss: 0.3498
# Epoch 14/15, Loss: 0.3493
# Epoch 15/15, Loss: 0.3558
# Mean Squared Error (MSE): 0.3823
# Root Mean Squared Error (RMSE): 0.6183
# R² Score: 0.7082
# Metrics: MSE=0.3823, RMSE=0.6183, R²=0.7082
# Tuning: batch_size=32, learning_rate=0.05, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 0.5161
# Epoch 2/5, Loss: 0.6384
# Epoch 3/5, Loss: 0.3994
# Epoch 4/5, Loss: 0.3802
# Epoch 5/5, Loss: 0.3695
# Mean Squared Error (MSE): 0.3923
# Root Mean Squared Error (RMSE): 0.6263
# R² Score: 0.7006
# Metrics: MSE=0.3923, RMSE=0.6263, R²=0.7006
# Tuning: batch_size=32, learning_rate=0.05, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 0.5027
# Epoch 2/10, Loss: 0.4177
# Epoch 3/10, Loss: 0.4105
# Epoch 4/10, Loss: 0.3982
# Epoch 5/10, Loss: 0.3975
# Epoch 6/10, Loss: 0.3791
# Epoch 7/10, Loss: 0.3740
# Epoch 8/10, Loss: 0.3680
# Epoch 9/10, Loss: 0.3585
# Epoch 10/10, Loss: 0.3645
# Mean Squared Error (MSE): 0.3368
# Root Mean Squared Error (RMSE): 0.5804
# R² Score: 0.7430
# Metrics: MSE=0.3368, RMSE=0.5804, R²=0.7430
# Tuning: batch_size=32, learning_rate=0.05, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 0.4876
# Epoch 2/15, Loss: 0.4050
# Epoch 3/15, Loss: 0.3816
# Epoch 4/15, Loss: 0.4359
# Epoch 5/15, Loss: 0.3939
# Epoch 6/15, Loss: 0.3730
# Epoch 7/15, Loss: 0.3685
# Epoch 8/15, Loss: 0.3635
# Epoch 9/15, Loss: 0.3634
# Epoch 10/15, Loss: 0.3665
# Epoch 11/15, Loss: 0.3630
# Epoch 12/15, Loss: 0.3778
# Epoch 13/15, Loss: 0.3635
# Epoch 14/15, Loss: 0.4758
# Epoch 15/15, Loss: 1.3463
# Mean Squared Error (MSE): 1.2991
# Root Mean Squared Error (RMSE): 1.1398
# R² Score: 0.0087
# Metrics: MSE=1.2991, RMSE=1.1398, R²=0.0087
# Tuning: batch_size=32, learning_rate=0.05, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 0.5633
# Epoch 2/5, Loss: 0.4086
# Epoch 3/5, Loss: 0.3916
# Epoch 4/5, Loss: 0.3959
# Epoch 5/5, Loss: 0.3863
# Mean Squared Error (MSE): 0.4158
# Root Mean Squared Error (RMSE): 0.6448
# R² Score: 0.6827
# Metrics: MSE=0.4158, RMSE=0.6448, R²=0.6827
# Tuning: batch_size=32, learning_rate=0.05, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 0.5511
# Epoch 2/10, Loss: 0.4069
# Epoch 3/10, Loss: 0.4154
# Epoch 4/10, Loss: 0.3874
# Epoch 5/10, Loss: 0.3871
# Epoch 6/10, Loss: 0.3884
# Epoch 7/10, Loss: 0.3850
# Epoch 8/10, Loss: 0.4005
# Epoch 9/10, Loss: 0.3869
# Epoch 10/10, Loss: 0.3835
# Mean Squared Error (MSE): 0.3957
# Root Mean Squared Error (RMSE): 0.6291
# R² Score: 0.6980
# Metrics: MSE=0.3957, RMSE=0.6291, R²=0.6980
# Tuning: batch_size=32, learning_rate=0.05, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 0.5017
# Epoch 2/15, Loss: 0.4172
# Epoch 3/15, Loss: 0.4053
# Epoch 4/15, Loss: 0.4443
# Epoch 5/15, Loss: 0.3959
# Epoch 6/15, Loss: 0.3979
# Epoch 7/15, Loss: 0.3882
# Epoch 8/15, Loss: 0.3853
# Epoch 9/15, Loss: 0.3844
# Epoch 10/15, Loss: 0.3756
# Epoch 11/15, Loss: 0.4266
# Epoch 12/15, Loss: 0.3856
# Epoch 13/15, Loss: 0.3755
# Epoch 14/15, Loss: 0.3752
# Epoch 15/15, Loss: 0.3717
# Mean Squared Error (MSE): 0.3680
# Root Mean Squared Error (RMSE): 0.6066
# R² Score: 0.7192
# Metrics: MSE=0.3680, RMSE=0.6066, R²=0.7192
# Tuning: batch_size=64, learning_rate=0.001, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 2.4101
# Epoch 2/5, Loss: 0.6310
# Epoch 3/5, Loss: 0.4818
# Epoch 4/5, Loss: 0.4323
# Epoch 5/5, Loss: 0.4160
# Mean Squared Error (MSE): 0.4264
# Root Mean Squared Error (RMSE): 0.6530
# R² Score: 0.6746
# Metrics: MSE=0.4264, RMSE=0.6530, R²=0.6746
# Tuning: batch_size=64, learning_rate=0.001, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 2.2124
# Epoch 2/10, Loss: 0.6732
# Epoch 3/10, Loss: 0.4897
# Epoch 4/10, Loss: 0.4234
# Epoch 5/10, Loss: 0.4052
# Epoch 6/10, Loss: 0.3955
# Epoch 7/10, Loss: 0.3864
# Epoch 8/10, Loss: 0.3789
# Epoch 9/10, Loss: 0.3736
# Epoch 10/10, Loss: 0.3628
# Mean Squared Error (MSE): 0.3751
# Root Mean Squared Error (RMSE): 0.6124
# R² Score: 0.7138
# Metrics: MSE=0.3751, RMSE=0.6124, R²=0.7138
# Tuning: batch_size=64, learning_rate=0.001, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 2.0053
# Epoch 2/15, Loss: 0.6156
# Epoch 3/15, Loss: 0.4690
# Epoch 4/15, Loss: 0.4322
# Epoch 5/15, Loss: 0.4129
# Epoch 6/15, Loss: 0.4022
# Epoch 7/15, Loss: 0.3928
# Epoch 8/15, Loss: 0.3870
# Epoch 9/15, Loss: 0.3794
# Epoch 10/15, Loss: 0.3734
# Epoch 11/15, Loss: 0.3689
# Epoch 12/15, Loss: 0.3623
# Epoch 13/15, Loss: 0.3596
# Epoch 14/15, Loss: 0.3535
# Epoch 15/15, Loss: 0.3488
# Mean Squared Error (MSE): 0.3759
# Root Mean Squared Error (RMSE): 0.6131
# R² Score: 0.7131
# Metrics: MSE=0.3759, RMSE=0.6131, R²=0.7131
# Tuning: batch_size=64, learning_rate=0.001, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 1.9690
# Epoch 2/5, Loss: 0.7112
# Epoch 3/5, Loss: 0.5901
# Epoch 4/5, Loss: 0.5024
# Epoch 5/5, Loss: 0.4476
# Mean Squared Error (MSE): 0.4473
# Root Mean Squared Error (RMSE): 0.6688
# R² Score: 0.6587
# Metrics: MSE=0.4473, RMSE=0.6688, R²=0.6587
# Tuning: batch_size=64, learning_rate=0.001, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 2.4805
# Epoch 2/10, Loss: 0.8424
# Epoch 3/10, Loss: 0.6759
# Epoch 4/10, Loss: 0.5956
# Epoch 5/10, Loss: 0.5172
# Epoch 6/10, Loss: 0.4539
# Epoch 7/10, Loss: 0.4308
# Epoch 8/10, Loss: 0.4182
# Epoch 9/10, Loss: 0.4076
# Epoch 10/10, Loss: 0.3997
# Mean Squared Error (MSE): 0.4097
# Root Mean Squared Error (RMSE): 0.6401
# R² Score: 0.6873
# Metrics: MSE=0.4097, RMSE=0.6401, R²=0.6873
# Tuning: batch_size=64, learning_rate=0.001, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 7.2579
# Epoch 2/15, Loss: 2.2741
# Epoch 3/15, Loss: 0.6547
# Epoch 4/15, Loss: 0.5408
# Epoch 5/15, Loss: 0.4875
# Epoch 6/15, Loss: 0.4590
# Epoch 7/15, Loss: 0.4425
# Epoch 8/15, Loss: 0.4310
# Epoch 9/15, Loss: 0.4230
# Epoch 10/15, Loss: 0.4160
# Epoch 11/15, Loss: 0.4099
# Epoch 12/15, Loss: 0.4051
# Epoch 13/15, Loss: 0.3992
# Epoch 14/15, Loss: 0.3945
# Epoch 15/15, Loss: 0.3897
# Mean Squared Error (MSE): 0.3999
# Root Mean Squared Error (RMSE): 0.6324
# R² Score: 0.6948
# Metrics: MSE=0.3999, RMSE=0.6324, R²=0.6948
# Tuning: batch_size=64, learning_rate=0.01, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 0.6627
# Epoch 2/5, Loss: 0.3777
# Epoch 3/5, Loss: 0.3615
# Epoch 4/5, Loss: 0.3466
# Epoch 5/5, Loss: 0.3392
# Mean Squared Error (MSE): 0.3508
# Root Mean Squared Error (RMSE): 0.5922
# R² Score: 0.7323
# Metrics: MSE=0.3508, RMSE=0.5922, R²=0.7323
# Tuning: batch_size=64, learning_rate=0.01, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 0.6210
# Epoch 2/10, Loss: 0.3735
# Epoch 3/10, Loss: 0.3557
# Epoch 4/10, Loss: 0.3422
# Epoch 5/10, Loss: 0.3491
# Epoch 6/10, Loss: 0.3361
# Epoch 7/10, Loss: 0.3242
# Epoch 8/10, Loss: 0.3197
# Epoch 9/10, Loss: 0.3175
# Epoch 10/10, Loss: 0.3135
# Mean Squared Error (MSE): 0.3462
# Root Mean Squared Error (RMSE): 0.5884
# R² Score: 0.7358
# Metrics: MSE=0.3462, RMSE=0.5884, R²=0.7358
# Tuning: batch_size=64, learning_rate=0.01, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 0.7218
# Epoch 2/15, Loss: 0.3859
# Epoch 3/15, Loss: 0.4136
# Epoch 4/15, Loss: 0.3565
# Epoch 5/15, Loss: 0.3551
# Epoch 6/15, Loss: 0.3399
# Epoch 7/15, Loss: 0.3288
# Epoch 8/15, Loss: 0.3270
# Epoch 9/15, Loss: 0.3206
# Epoch 10/15, Loss: 0.3162
# Epoch 11/15, Loss: 0.3133
# Epoch 12/15, Loss: 0.3171
# Epoch 13/15, Loss: 0.3053
# Epoch 14/15, Loss: 0.3050
# Epoch 15/15, Loss: 0.3071
# Mean Squared Error (MSE): 0.3051
# Root Mean Squared Error (RMSE): 0.5524
# R² Score: 0.7672
# Metrics: MSE=0.3051, RMSE=0.5524, R²=0.7672
# Tuning: batch_size=64, learning_rate=0.01, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 0.9511
# Epoch 2/5, Loss: 0.4137
# Epoch 3/5, Loss: 0.3956
# Epoch 4/5, Loss: 0.4067
# Epoch 5/5, Loss: 0.3850
# Mean Squared Error (MSE): 0.3917
# Root Mean Squared Error (RMSE): 0.6258
# R² Score: 0.7011
# Metrics: MSE=0.3917, RMSE=0.6258, R²=0.7011
# Tuning: batch_size=64, learning_rate=0.01, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 0.7407
# Epoch 2/10, Loss: 0.4157
# Epoch 3/10, Loss: 0.4121
# Epoch 4/10, Loss: 0.3946
# Epoch 5/10, Loss: 0.3929
# Epoch 6/10, Loss: 0.3592
# Epoch 7/10, Loss: 0.3495
# Epoch 8/10, Loss: 0.3468
# Epoch 9/10, Loss: 0.3414
# Epoch 10/10, Loss: 0.3367
# Mean Squared Error (MSE): 0.3382
# Root Mean Squared Error (RMSE): 0.5815
# R² Score: 0.7419
# Metrics: MSE=0.3382, RMSE=0.5815, R²=0.7419
# Tuning: batch_size=64, learning_rate=0.01, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 3.9632
# Epoch 2/15, Loss: 1.4455
# Epoch 3/15, Loss: 0.8985
# Epoch 4/15, Loss: 0.5743
# Epoch 5/15, Loss: 0.4762
# Epoch 6/15, Loss: 0.4748
# Epoch 7/15, Loss: 0.4075
# Epoch 8/15, Loss: 0.3847
# Epoch 9/15, Loss: 0.3757
# Epoch 10/15, Loss: 0.3721
# Epoch 11/15, Loss: 0.3630
# Epoch 12/15, Loss: 0.3623
# Epoch 13/15, Loss: 0.3618
# Epoch 14/15, Loss: 0.3629
# Epoch 15/15, Loss: 0.3567
# Mean Squared Error (MSE): 0.3737
# Root Mean Squared Error (RMSE): 0.6113
# R² Score: 0.7148
# Metrics: MSE=0.3737, RMSE=0.6113, R²=0.7148
# Tuning: batch_size=64, learning_rate=0.05, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 0.7211
# Epoch 2/5, Loss: 0.6845
# Epoch 3/5, Loss: 0.3722
# Epoch 4/5, Loss: 0.3608
# Epoch 5/5, Loss: 0.3730
# Mean Squared Error (MSE): 0.3693
# Root Mean Squared Error (RMSE): 0.6077
# R² Score: 0.7182
# Metrics: MSE=0.3693, RMSE=0.6077, R²=0.7182
# Tuning: batch_size=64, learning_rate=0.05, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 0.5194
# Epoch 2/10, Loss: 0.3991
# Epoch 3/10, Loss: 0.3700
# Epoch 4/10, Loss: 0.3586
# Epoch 5/10, Loss: 0.3903
# Epoch 6/10, Loss: 0.3662
# Epoch 7/10, Loss: 0.3605
# Epoch 8/10, Loss: 0.3464
# Epoch 9/10, Loss: 0.3402
# Epoch 10/10, Loss: 0.3323
# Mean Squared Error (MSE): 0.4311
# Root Mean Squared Error (RMSE): 0.6566
# R² Score: 0.6710
# Metrics: MSE=0.4311, RMSE=0.6566, R²=0.6710
# Tuning: batch_size=64, learning_rate=0.05, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 0.5212
# Epoch 2/15, Loss: 0.3850
# Epoch 3/15, Loss: 0.3797
# Epoch 4/15, Loss: 0.3860
# Epoch 5/15, Loss: 0.3566
# Epoch 6/15, Loss: 0.3471
# Epoch 7/15, Loss: 0.3530
# Epoch 8/15, Loss: 0.3431
# Epoch 9/15, Loss: 0.3479
# Epoch 10/15, Loss: 0.3584
# Epoch 11/15, Loss: 0.3453
# Epoch 12/15, Loss: 0.3445
# Epoch 13/15, Loss: 0.3442
# Epoch 14/15, Loss: 0.3386
# Epoch 15/15, Loss: 0.3506
# Mean Squared Error (MSE): 0.4244
# Root Mean Squared Error (RMSE): 0.6514
# R² Score: 0.6762
# Metrics: MSE=0.4244, RMSE=0.6514, R²=0.6762
# Tuning: batch_size=64, learning_rate=0.05, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 0.6522
# Epoch 2/5, Loss: 0.4295
# Epoch 3/5, Loss: 0.4278
# Epoch 4/5, Loss: 0.4221
# Epoch 5/5, Loss: 0.4188
# Mean Squared Error (MSE): 0.4369
# Root Mean Squared Error (RMSE): 0.6610
# R² Score: 0.6666
# Metrics: MSE=0.4369, RMSE=0.6610, R²=0.6666
# Tuning: batch_size=64, learning_rate=0.05, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 0.6455
# Epoch 2/10, Loss: 0.3959
# Epoch 3/10, Loss: 0.3907
# Epoch 4/10, Loss: 0.3805
# Epoch 5/10, Loss: 0.3759
# Epoch 6/10, Loss: 0.3655
# Epoch 7/10, Loss: 0.3660
# Epoch 8/10, Loss: 0.3625
# Epoch 9/10, Loss: 0.3636
# Epoch 10/10, Loss: 0.3613
# Mean Squared Error (MSE): 0.4643
# Root Mean Squared Error (RMSE): 0.6814
# R² Score: 0.6457
# Metrics: MSE=0.4643, RMSE=0.6814, R²=0.6457
# Tuning: batch_size=64, learning_rate=0.05, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 0.5209
# Epoch 2/15, Loss: 0.4472
# Epoch 3/15, Loss: 0.4076
# Epoch 4/15, Loss: 0.4132
# Epoch 5/15, Loss: 0.4092
# Epoch 6/15, Loss: 0.4041
# Epoch 7/15, Loss: 0.4117
# Epoch 8/15, Loss: 0.4036
# Epoch 9/15, Loss: 0.3918
# Epoch 10/15, Loss: 0.3811
# Epoch 11/15, Loss: 0.3736
# Epoch 12/15, Loss: 0.4074
# Epoch 13/15, Loss: 0.3695
# Epoch 14/15, Loss: 0.3743
# Epoch 15/15, Loss: 0.3647
# Mean Squared Error (MSE): 0.3796
# Root Mean Squared Error (RMSE): 0.6161
# R² Score: 0.7103
# Metrics: MSE=0.3796, RMSE=0.6161, R²=0.7103
# Tuning: batch_size=128, learning_rate=0.001, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 2.5296
# Epoch 2/5, Loss: 0.7243
# Epoch 3/5, Loss: 0.5947
# Epoch 4/5, Loss: 0.5207
# Epoch 5/5, Loss: 0.4747
# Mean Squared Error (MSE): 0.4689
# Root Mean Squared Error (RMSE): 0.6847
# R² Score: 0.6422
# Metrics: MSE=0.4689, RMSE=0.6847, R²=0.6422
# Tuning: batch_size=128, learning_rate=0.001, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 3.6558
# Epoch 2/10, Loss: 0.9884
# Epoch 3/10, Loss: 0.6830
# Epoch 4/10, Loss: 0.5618
# Epoch 5/10, Loss: 0.4883
# Epoch 6/10, Loss: 0.4507
# Epoch 7/10, Loss: 0.4298
# Epoch 8/10, Loss: 0.4164
# Epoch 9/10, Loss: 0.4058
# Epoch 10/10, Loss: 0.3965
# Mean Squared Error (MSE): 0.4061
# Root Mean Squared Error (RMSE): 0.6372
# R² Score: 0.6901
# Metrics: MSE=0.4061, RMSE=0.6372, R²=0.6901
# Tuning: batch_size=128, learning_rate=0.001, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 2.6990
# Epoch 2/15, Loss: 0.9072
# Epoch 3/15, Loss: 0.6634
# Epoch 4/15, Loss: 0.5442
# Epoch 5/15, Loss: 0.4827
# Epoch 6/15, Loss: 0.4512
# Epoch 7/15, Loss: 0.4331
# Epoch 8/15, Loss: 0.4198
# Epoch 9/15, Loss: 0.4080
# Epoch 10/15, Loss: 0.3994
# Epoch 11/15, Loss: 0.3916
# Epoch 12/15, Loss: 0.3841
# Epoch 13/15, Loss: 0.3766
# Epoch 14/15, Loss: 0.3711
# Epoch 15/15, Loss: 0.3646
# Mean Squared Error (MSE): 0.3784
# Root Mean Squared Error (RMSE): 0.6151
# R² Score: 0.7113
# Metrics: MSE=0.3784, RMSE=0.6151, R²=0.7113
# Tuning: batch_size=128, learning_rate=0.001, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 6.1133
# Epoch 2/5, Loss: 3.7776
# Epoch 3/5, Loss: 1.3451
# Epoch 4/5, Loss: 0.7870
# Epoch 5/5, Loss: 0.6777
# Mean Squared Error (MSE): 0.6546
# Root Mean Squared Error (RMSE): 0.8091
# R² Score: 0.5004
# Metrics: MSE=0.6546, RMSE=0.8091, R²=0.5004
# Tuning: batch_size=128, learning_rate=0.001, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 2.4260
# Epoch 2/10, Loss: 1.1601
# Epoch 3/10, Loss: 0.6808
# Epoch 4/10, Loss: 0.5690
# Epoch 5/10, Loss: 0.5180
# Epoch 6/10, Loss: 0.4864
# Epoch 7/10, Loss: 0.4676
# Epoch 8/10, Loss: 0.4543
# Epoch 9/10, Loss: 0.4444
# Epoch 10/10, Loss: 0.4362
# Mean Squared Error (MSE): 0.4442
# Root Mean Squared Error (RMSE): 0.6665
# R² Score: 0.6610
# Metrics: MSE=0.4442, RMSE=0.6665, R²=0.6610
# Tuning: batch_size=128, learning_rate=0.001, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 5.2404
# Epoch 2/15, Loss: 2.9545
# Epoch 3/15, Loss: 1.3612
# Epoch 4/15, Loss: 0.8186
# Epoch 5/15, Loss: 0.6891
# Epoch 6/15, Loss: 0.6262
# Epoch 7/15, Loss: 0.5809
# Epoch 8/15, Loss: 0.5460
# Epoch 9/15, Loss: 0.5195
# Epoch 10/15, Loss: 0.5007
# Epoch 11/15, Loss: 0.4882
# Epoch 12/15, Loss: 0.4784
# Epoch 13/15, Loss: 0.4710
# Epoch 14/15, Loss: 0.4639
# Epoch 15/15, Loss: 0.4586
# Mean Squared Error (MSE): 0.4751
# Root Mean Squared Error (RMSE): 0.6892
# R² Score: 0.6375
# Metrics: MSE=0.4751, RMSE=0.6892, R²=0.6375
# Tuning: batch_size=128, learning_rate=0.01, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 0.7885
# Epoch 2/5, Loss: 0.4137
# Epoch 3/5, Loss: 0.3799
# Epoch 4/5, Loss: 0.3688
# Epoch 5/5, Loss: 0.3598
# Mean Squared Error (MSE): 0.3588
# Root Mean Squared Error (RMSE): 0.5990
# R² Score: 0.7262
# Metrics: MSE=0.3588, RMSE=0.5990, R²=0.7262
# Tuning: batch_size=128, learning_rate=0.01, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 0.9861
# Epoch 2/10, Loss: 0.4088
# Epoch 3/10, Loss: 0.3900
# Epoch 4/10, Loss: 0.3651
# Epoch 5/10, Loss: 0.3671
# Epoch 6/10, Loss: 0.3520
# Epoch 7/10, Loss: 0.3467
# Epoch 8/10, Loss: 0.3439
# Epoch 9/10, Loss: 0.3446
# Epoch 10/10, Loss: 0.3483
# Mean Squared Error (MSE): 0.3428
# Root Mean Squared Error (RMSE): 0.5855
# R² Score: 0.7384
# Metrics: MSE=0.3428, RMSE=0.5855, R²=0.7384
# Tuning: batch_size=128, learning_rate=0.01, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 0.8795
# Epoch 2/15, Loss: 0.4034
# Epoch 3/15, Loss: 0.3857
# Epoch 4/15, Loss: 0.3641
# Epoch 5/15, Loss: 0.3544
# Epoch 6/15, Loss: 0.3496
# Epoch 7/15, Loss: 0.3380
# Epoch 8/15, Loss: 0.3323
# Epoch 9/15, Loss: 0.3294
# Epoch 10/15, Loss: 0.3170
# Epoch 11/15, Loss: 0.3147
# Epoch 12/15, Loss: 0.3207
# Epoch 13/15, Loss: 0.3153
# Epoch 14/15, Loss: 0.3091
# Epoch 15/15, Loss: 0.3065
# Mean Squared Error (MSE): 0.3194
# Root Mean Squared Error (RMSE): 0.5652
# R² Score: 0.7562
# Metrics: MSE=0.3194, RMSE=0.5652, R²=0.7562
# Tuning: batch_size=128, learning_rate=0.01, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 1.2342
# Epoch 2/5, Loss: 0.4336
# Epoch 3/5, Loss: 0.4218
# Epoch 4/5, Loss: 0.4115
# Epoch 5/5, Loss: 0.4086
# Mean Squared Error (MSE): 0.4039
# Root Mean Squared Error (RMSE): 0.6355
# R² Score: 0.6918
# Metrics: MSE=0.4039, RMSE=0.6355, R²=0.6918
# Tuning: batch_size=128, learning_rate=0.01, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 1.6669
# Epoch 2/10, Loss: 0.4654
# Epoch 3/10, Loss: 0.4257
# Epoch 4/10, Loss: 0.4148
# Epoch 5/10, Loss: 0.4101
# Epoch 6/10, Loss: 0.4056
# Epoch 7/10, Loss: 0.4081
# Epoch 8/10, Loss: 0.3895
# Epoch 9/10, Loss: 0.3750
# Epoch 10/10, Loss: 0.3649
# Mean Squared Error (MSE): 0.4052
# Root Mean Squared Error (RMSE): 0.6365
# R² Score: 0.6908
# Metrics: MSE=0.4052, RMSE=0.6365, R²=0.6908
# Tuning: batch_size=128, learning_rate=0.01, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 4.4013
# Epoch 2/15, Loss: 0.4948
# Epoch 3/15, Loss: 0.4143
# Epoch 4/15, Loss: 0.4037
# Epoch 5/15, Loss: 0.3943
# Epoch 6/15, Loss: 0.3892
# Epoch 7/15, Loss: 0.3828
# Epoch 8/15, Loss: 0.3873
# Epoch 9/15, Loss: 0.3795
# Epoch 10/15, Loss: 0.3746
# Epoch 11/15, Loss: 0.3707
# Epoch 12/15, Loss: 0.3670
# Epoch 13/15, Loss: 0.3685
# Epoch 14/15, Loss: 0.3730
# Epoch 15/15, Loss: 0.3650
# Mean Squared Error (MSE): 0.3745
# Root Mean Squared Error (RMSE): 0.6120
# R² Score: 0.7142
# Metrics: MSE=0.3745, RMSE=0.6120, R²=0.7142
# Tuning: batch_size=128, learning_rate=0.05, hidden_layers=[24, 12], epochs=5
# Epoch 1/5, Loss: 0.6188
# Epoch 2/5, Loss: 0.3825
# Epoch 3/5, Loss: 0.3984
# Epoch 4/5, Loss: 0.3644
# Epoch 5/5, Loss: 0.3724
# Mean Squared Error (MSE): 0.3730
# Root Mean Squared Error (RMSE): 0.6107
# R² Score: 0.7154
# Metrics: MSE=0.3730, RMSE=0.6107, R²=0.7154
# Tuning: batch_size=128, learning_rate=0.05, hidden_layers=[24, 12], epochs=10
# Epoch 1/10, Loss: 0.5784
# Epoch 2/10, Loss: 0.3880
# Epoch 3/10, Loss: 0.3619
# Epoch 4/10, Loss: 0.3573
# Epoch 5/10, Loss: 0.4554
# Epoch 6/10, Loss: 0.3534
# Epoch 7/10, Loss: 0.3418
# Epoch 8/10, Loss: 0.3367
# Epoch 9/10, Loss: 0.3572
# Epoch 10/10, Loss: 0.3272
# Mean Squared Error (MSE): 0.3163
# Root Mean Squared Error (RMSE): 0.5624
# R² Score: 0.7586
# Metrics: MSE=0.3163, RMSE=0.5624, R²=0.7586
# Tuning: batch_size=128, learning_rate=0.05, hidden_layers=[24, 12], epochs=15
# Epoch 1/15, Loss: 0.5946
# Epoch 2/15, Loss: 0.3970
# Epoch 3/15, Loss: 0.3648
# Epoch 4/15, Loss: 0.3528
# Epoch 5/15, Loss: 0.3493
# Epoch 6/15, Loss: 0.3342
# Epoch 7/15, Loss: 0.3321
# Epoch 8/15, Loss: 0.3382
# Epoch 9/15, Loss: 0.3330
# Epoch 10/15, Loss: 0.3201
# Epoch 11/15, Loss: 0.3292
# Epoch 12/15, Loss: 0.3303
# Epoch 13/15, Loss: 0.3376
# Epoch 14/15, Loss: 0.3519
# Epoch 15/15, Loss: 0.3385
# Mean Squared Error (MSE): 0.3155
# Root Mean Squared Error (RMSE): 0.5617
# R² Score: 0.7592
# Metrics: MSE=0.3155, RMSE=0.5617, R²=0.7592
# Tuning: batch_size=128, learning_rate=0.05, hidden_layers=[6, 3], epochs=5
# Epoch 1/5, Loss: 0.9714
# Epoch 2/5, Loss: 0.4202
# Epoch 3/5, Loss: 0.4057
# Epoch 4/5, Loss: 0.3997
# Epoch 5/5, Loss: 0.4033
# Mean Squared Error (MSE): 0.3884
# Root Mean Squared Error (RMSE): 0.6232
# R² Score: 0.7036
# Metrics: MSE=0.3884, RMSE=0.6232, R²=0.7036
# Tuning: batch_size=128, learning_rate=0.05, hidden_layers=[6, 3], epochs=10
# Epoch 1/10, Loss: 0.7225
# Epoch 2/10, Loss: 0.4212
# Epoch 3/10, Loss: 0.3992
# Epoch 4/10, Loss: 0.3969
# Epoch 5/10, Loss: 0.3804
# Epoch 6/10, Loss: 0.3797
# Epoch 7/10, Loss: 0.3770
# Epoch 8/10, Loss: 0.3759
# Epoch 9/10, Loss: 0.3669
# Epoch 10/10, Loss: 0.3680
# Mean Squared Error (MSE): 0.3686
# Root Mean Squared Error (RMSE): 0.6071
# R² Score: 0.7187
# Metrics: MSE=0.3686, RMSE=0.6071, R²=0.7187
# Tuning: batch_size=128, learning_rate=0.05, hidden_layers=[6, 3], epochs=15
# Epoch 1/15, Loss: 0.8435
# Epoch 2/15, Loss: 0.3900
# Epoch 3/15, Loss: 0.3905
# Epoch 4/15, Loss: 0.3716
# Epoch 5/15, Loss: 0.3579
# Epoch 6/15, Loss: 0.3510
# Epoch 7/15, Loss: 0.3643
# Epoch 8/15, Loss: 0.3468
# Epoch 9/15, Loss: 0.3432
# Epoch 10/15, Loss: 0.3386
# Epoch 11/15, Loss: 0.3489
# Epoch 12/15, Loss: 0.3399
# Epoch 13/15, Loss: 0.3463
# Epoch 14/15, Loss: 0.3547
# Epoch 15/15, Loss: 0.3477
# Mean Squared Error (MSE): 0.3510
# Root Mean Squared Error (RMSE): 0.5925
# R² Score: 0.7321
# Metrics: MSE=0.3510, RMSE=0.5925, R²=0.7321
# Best Configuration: batch_size=64, learning_rate=0.01, hidden_layers=[24, 12], epochs=15, R²=0.7672
